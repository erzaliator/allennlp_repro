# %% [markdown]
# # 4️⃣ Zero-Shot Cross-Lingual Transfer using Adapters
#
# Beyond AdapterFusion, which we trained in [the previous notebook](https://github.com/Adapter-Hub/adapter-transformers/blob/master/notebooks/04_Cross_Lingual_Transfer.ipynb), we can compose adapters for zero-shot cross-lingual transfer between tasks. We will use the stacked adapter setup presented in **MAD-X** ([Pfeiffer et al., 2020](https://arxiv.org/pdf/2005.00052.pdf)) for this purpose.
#
# In this example, the base model is a pre-trained multilingual **XLM-R** (`xlm-roberta-base`) ([Conneau et al., 2019](https://arxiv.org/pdf/1911.02116.pdf)) model. Additionally, two types of adapters, language adapters and task adapters, are used. Here's how the MAD-X process works in detail:
#
# 1. Train language adapters for the source and target language on a language modeling task. In this notebook, we won't train them ourselves but use [pre-trained language adapters from the Hub](https://adapterhub.ml/explore/text_lang/).
# 2. Train a task adapter on the target task dataset. This task adapter is **stacked** upon the previously trained language adapter. During this step, only the weights of the task adapter are updated.
# 3. Perform zero-shot cross-lingual transfer. In this last step, we simply replace the source language adapter with the target language adapter while keeping the stacked task adapter.
#
# Now to our concrete example: we select **XCOPA** ([Ponti et al., 2020](https://ducdauge.github.io/files/xcopa.pdf)), a multilingual extension of the **COPA** commonsence reasoning dataset ([Roemmele et al., 2011](https://people.ict.usc.edu/~gordon/publications/AAAI-SPRING11A.PDF)) as our target task. The setup is trained on the original **English** dataset and then transferred to **Chinese**.

# %% [markdown]
# ## Installation
#
# Besides `adapter-transformers`, we use HuggingFace's `datasets` library for loading the data. So let's install both first:

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="5"
# os.environ["CUDA_VISIBLE_DEVICES"]="-1"

import torch
import wandb

# %%
SEED = 42
BERT_MODEL = 'bert-base-multilingual-cased'#'bert-base-german-cased'
BATCH_SIZE = 8

# %%
experiment_name = 'AdapterAlpha'
lr = 'lr=AdafactorDefault'
model_name = 'plm='+BERT_MODEL
additional_info = 'Info=v3_lrtest1'
name = '_'.join([experiment_name, lr, model_name, additional_info])

MODEL_DIR = name

# %%
#WANDB
wandb.init(reinit=True)
wandb.run.name = name
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: erzaliator. Use `wandb login --relogin` to force relogin
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/home/VD/kaveri/bert_categorical_tutorial/allennlp_repro/disrpt_alln/4_adapter/wandb/run-20230109_135100-1mb7oj6u</code>
# Syncing run <strong><a href="https://wandb.ai/erzaliator/allennlp_repro-disrpt_alln_4_adapter/runs/1mb7oj6u" target="_blank">northern-resonance-35</a></strong> to <a href="https://wandb.ai/erzaliator/allennlp_repro-disrpt_alln_4_adapter" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
# LOGGING
from utils.logger import Logger
logger = Logger(MODEL_DIR, wandb, wandb_flag=True)
print('Running with params: BERT_MODEL='+ BERT_MODEL+ ' lr='+ str(lr))
# Out:
# Running with params: BERT_MODEL=bert-base-multilingual-cased lr=lr=AdafactorDefault

# %% [markdown]
# ## Dataset Preprocessing
#
# We need the English COPA dataset for training our task adapter. It is part of the SuperGLUE benchmark and can be loaded via `datasets` using one line of code:

# %%
import pandas as pd
from datasets import Dataset

def read_df_custom(file):
    header = 'doc     unit1_toks      unit2_toks      unit1_txt       unit2_txt       s1_toks s2_toks unit1_sent      unit2_sent      dir     nuc_children    sat_children    genre   u1_discontinuous        u2_discontinuous       u1_issent        u2_issent       u1_length       u2_length       length_ratio    u1_speaker      u2_speaker      same_speaker    u1_func u1_pos  u1_depdir       u2_func u2_pos  u2_depdir       doclen  u1_position      u2_position     percent_distance        distance        lex_overlap_words       lex_overlap_length      unit1_case      unit2_case      label'
    extracted_columns = ['unit1_txt', 'unit1_sent', 'unit2_txt', 'unit2_sent', 'dir', 'label', 'distance', 'u1_depdir', 'u2_depdir', 'u2_func', 'u1_position', 'u2_position', 'sat_children', 'nuc_children', 'genre', 'unit1_case', 'unit2_case',
                            'u1_discontinuous', 'u2_discontinuous', 'same_speaker', 'lex_overlap_length', 'u1_func']
    header = header.split()
    df = pd.DataFrame(columns=extracted_columns)
    file = open(file, 'r')

    rows = []
    count = 0 
    for line in file:
        line = line[:-1].split('\t')
        count+=1
        if count ==1: continue
        row = {}
        for column in extracted_columns:
            index = header.index(column)
            row[column] = line[index]
        rows.append(row)

    df = pd.concat([df, pd.DataFrame.from_records(rows)])
    return df

en_train_dataset_df = Dataset.from_pandas(read_df_custom('../../processed/eng.rst.rstdt_train_enriched.rels'))
en_test_dataset_df = Dataset.from_pandas(read_df_custom('../../processed/eng.rst.rstdt_test_enriched.rels'))
en_valid_dataset_df = Dataset.from_pandas(read_df_custom('../../processed/eng.rst.rstdt_dev_enriched.rels'))

de_train_dataset_df = Dataset.from_pandas(read_df_custom('../../processed/deu.rst.pcc_train_enriched.rels'))
de_test_dataset_df = Dataset.from_pandas(read_df_custom('../../processed/deu.rst.pcc_test_enriched.rels'))
de_valid_dataset_df = Dataset.from_pandas(read_df_custom('../../processed/deu.rst.pcc_dev_enriched.rels'))

len(en_train_dataset_df), len(en_test_dataset_df), len(en_valid_dataset_df)
# Out:
# (16002, 2155, 1621)

# %%
en_train_dataset_df.features
# Out:
# {'unit1_txt': Value(dtype='string', id=None),
#  'unit1_sent': Value(dtype='string', id=None),
#  'unit2_txt': Value(dtype='string', id=None),
#  'unit2_sent': Value(dtype='string', id=None),
#  'dir': Value(dtype='string', id=None),
#  'label': Value(dtype='string', id=None),
#  'distance': Value(dtype='string', id=None),
#  'u1_depdir': Value(dtype='string', id=None),
#  'u2_depdir': Value(dtype='string', id=None),
#  'u2_func': Value(dtype='string', id=None),
#  'u1_position': Value(dtype='string', id=None),
#  'u2_position': Value(dtype='string', id=None),
#  'sat_children': Value(dtype='string', id=None),
#  'nuc_children': Value(dtype='string', id=None),
#  'genre': Value(dtype='string', id=None),
#  'unit1_case': Value(dtype='string', id=None),
#  'unit2_case': Value(dtype='string', id=None),
#  'u1_discontinuous': Value(dtype='string', id=None),
#  'u2_discontinuous': Value(dtype='string', id=None),
#  'same_speaker': Value(dtype='string', id=None),
#  'lex_overlap_length': Value(dtype='string', id=None),
#  'u1_func': Value(dtype='string', id=None),
#  '__index_level_0__': Value(dtype='int64', id=None)}

# %% [markdown]
# In this example, we model COPA as a multiple-choice task with two choices. Thus, we encode the premise and question as well as both choices as one input to our `xlm-roberta-base` model. Using `dataset.map()`, we can pass the full dataset through the tokenizer in batches:

# %%
from transformers import AutoTokenizer, BertTokenizer
from datasets import ClassLabel

tokenizer = AutoTokenizer.from_pretrained(BERT_MODEL)

class SNLIDataset(torch.utils.data.Dataset):
    """A customized dataset to load the SNLI dataset."""
    def __init__(self, dataset, labels, raw_text=False):
        self.text = []
        self.raw_text = []
        self.raw_label = []
        self.raw_text_flag = raw_text
        self.num_rows = len(dataset)
        for premise, hypothesis in zip(dataset['unit1_txt'], dataset['unit2_txt']):
            self.text.append(tokenizer.encode_plus(premise, hypothesis, padding="max_length", truncation=True, max_length=512, return_token_type_ids=True))
            if raw_text: self.raw_text.append([premise, hypothesis])
        # self.labels = torch.tensor(labels.str2int(dataset['label'])).to(device)
        self.labels = labels.str2int(dataset['label'])
        if raw_text: self.raw_label = dataset['label']
        print('read ' + str(len(self.text)) + ' examples')

    def __getitem__(self, idx):
        if self.raw_text_flag:  
            return {'input_ids':self.text[idx]['input_ids'], 
                'token_type_ids':self.text[idx]['token_type_ids'], 
                'attention_mask':self.text[idx]['attention_mask'], 
                'raw_text': self.raw_text[idx],
                'label':self.labels[idx],
                'raw_label': self.raw_label[idx]}

        return {'input_ids':self.text[idx]['input_ids'], 
                'token_type_ids':self.text[idx]['token_type_ids'], 
                'attention_mask':self.text[idx]['attention_mask'], 
                'label':self.labels[idx]}

    def __len__(self):
        return len(self.text)

    def combine_with_another_dataset(self, dataset2):
        print('Adding datasets of sizes ', self.num_rows, ', ', dataset2.num_rows)
        self.text = self.text + dataset2.text
        self.raw_text = self.raw_text + dataset2.raw_text
        self.raw_label = self.raw_label + dataset2.raw_label
        self.num_rows = len(self.text) #update texts is now longer
        assert self.raw_text_flag == dataset2.raw_text_flag
        print('To new dataset size: ', self.num_rows)


def load_data_snli(batch_size, train_dataset_df, valid_dataset_df, test_dataset_df, labels):
    """Download the SNLI dataset and return data iterators and vocabulary."""
    train_data = train_dataset_df
    valid_data = valid_dataset_df
    test_data = test_dataset_df
    train_set = SNLIDataset(train_data, labels, raw_text=False)
    valid_set = SNLIDataset(valid_data, labels, raw_text=False)
    test_set = SNLIDataset(test_data, labels, raw_text=False)
    return train_set, valid_set, test_set #TODO: MAKE INTO DICT

en_labels = ClassLabel(names=list(set(en_train_dataset_df['label'])|set(en_test_dataset_df['label'])|set(en_valid_dataset_df['label'])))
en_train_dataset, en_valid_dataset, en_test_dataset = load_data_snli(BATCH_SIZE, en_train_dataset_df, en_valid_dataset_df, en_test_dataset_df, en_labels)
de_labels = ClassLabel(names=list(set(de_train_dataset_df['label'])|set(de_test_dataset_df['label'])|set(de_valid_dataset_df['label'])))
de_train_dataset, de_valid_dataset, de_test_dataset = load_data_snli(BATCH_SIZE, de_train_dataset_df, de_valid_dataset_df, de_test_dataset_df, de_labels)
# Out:
# read 16002 examples
# read 1621 examples
# read 2155 examples
# read 2164 examples
# read 241 examples
# read 260 examples

# %% [markdown]
# ## Task Adapter Training
#
# In this section, we will train the task adapter on the English COPA dataset. We use a pre-trained XLM-R model from HuggingFace and instantiate our model using `AutoAdapterModel`.

# %%
from transformers import AutoConfig, AutoAdapterModel

config = AutoConfig.from_pretrained(
    BERT_MODEL,
)
model = AutoAdapterModel.from_pretrained(
    BERT_MODEL,
    config=config,
)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertAdapterModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertAdapterModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertAdapterModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# This is the base AutoModel. If you print model before adding the adapters, you can see that the embeddings+12 transformer layers will be shared by En and Zh adapters.

# %% [markdown]
# Now we only need to set up the adapters. As described, we need two language adapters (which are assumed to be pre-trained in this example) and a task adapter (which will be trained in a few moments).
#
# First, we load both the language adapters for our source language English (`"en"`) and our target language Chinese (`"zh"`) from the Hub. Then we add a new task adapter (`"copa"`) for our target task.
#
# Finally, we add a multiple-choice head with the same name as our task adapter on top.

# %%
from transformers import AdapterConfig

# Load the language adapters
lang_adapter_config = AdapterConfig.load("pfeiffer", reduction_factor=2)
model.load_adapter("en/wiki@ukp", config=lang_adapter_config)
model.load_adapter("de/wiki@ukp", config=lang_adapter_config)

# Add a new task adapter
# model.add_adapter_task("disrpt", labels=[1,0,0,0,0,0,0])
model.add_adapter("disrpt")

# Add a classification head for our target task
num_labels=de_labels.num_classes
print([num_labels])
# model.add_multiple_choice_head("disrpt", num_choices=num_labels)
model.add_classification_head("disrpt", num_labels=num_labels)
# Out:
# [26]

# %% [markdown]
# Using `train_adapter()`, we tell our model to only train the task adapter in the following. This call will freeze the weights of the pre-trained model and the weights of the language adapters to prevent them from further finetuning.

# %%
model.train_adapter(["disrpt"])

# %% [markdown]
# We want the task adapter to be stacked on top of the language adapter, so we have to tell our model to use this setup via the `active_adapters` property.
#
# A stack of adapters is represented by the `Stack` class, which takes the names of the adapters to be stacked as arguments.
# Of course, there are various other possibilities to compose adapters beyonde stacking. Learn more about those [in our documentation](https://docs.adapterhub.ml/adapter_composition.html).

# %%
# Unfreeze and activate stack setup
from transformers.adapters.composition import Stack

lang = 'en'
model.active_adapters = Stack(lang, "disrpt")

# %% [markdown]
# Great! Now, the input will be passed through the English language adapter first and the COPA task adapter second in every forward pass.

# %% [markdown]
# For training, we make use of the `Trainer` class built-in into `transformers`. We configure the training process using a `TrainingArguments` object.
#
# As the dataset splits of English COPA in the SuperGLUE are slightly different, we train on both the train and validation split of the dataset. Later, we will evaluate on the test split of XCOPA.

# %%
# TODO: SHUFFLE print smples: https://discuss.huggingface.co/t/how-to-print-a-few-examples-at-the-beginning-of-training-when-using-trainer/7597/2
# https://github.com/huggingface/datasets/blob/cd3169f3f35afcf73a36a8276113e1881d92e5e0/src/datasets/iterable_dataset.py#L223

# %%
from copy import deepcopy
from transformers import TrainerCallback

class CustomCallback(TrainerCallback):
    
    def __init__(self, trainer) -> None:
        super().__init__()
        self._trainer = trainer
    
    def on_epoch_end(self, args, state, control, **kwargs):
        if control.should_evaluate:
            control_copy = deepcopy(control)
            self._trainer.evaluate(eval_dataset=self._trainer.train_dataset, metric_key_prefix="train@"+lang)
            return control_copy
# Out:
# 2023-01-09 13:51:36.382422: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-09 13:51:36.675851: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda-10.1/lib64:/usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda-10.2/targets/x86_64-linux/lib/:/usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-01-09 13:51:36.675897: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-01-09 13:51:36.719216: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-01-09 13:51:38.008490: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda-10.1/lib64:/usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda-10.2/targets/x86_64-linux/lib/:/usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-01-09 13:51:38.008621: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda-10.1/lib64:/usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda-10.2/targets/x86_64-linux/lib/:/usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-01-09 13:51:38.008630: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
from sklearn.metrics import precision_recall_fscore_support, accuracy_score, log_loss
from torch.nn import CrossEntropyLoss
import numpy as np

def compute_metrics(pred):
    global num_labels
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='macro')
    acc = accuracy_score(labels, preds)
    loss_fct = CrossEntropyLoss()
    logits = torch.tensor(pred.predictions)
    labels = torch.tensor(labels)
    loss = loss_fct(logits.view(-1, num_labels), labels.view(-1))
    return {
        'accuracy@'+lang: acc,
        'f1@'+lang: f1,
        'precision@'+lang: precision,
        'recall@'+lang: recall,
        'loss@'+lang: loss,
    }

# %%
from transformers import TrainingArguments, AdapterTrainer
# from datasets import concatenate_datasets
from itertools import chain


def concatenate_datasets(dataset1, dataset2, shuffle=True):
    y_iter = chain(dataset1, dataset2)
    return y_iter
    # tmp = list(yielding(y_iter))
    # random.shuffle(tmp)
    # for i in tmp:
    #     print i

training_args = TrainingArguments(
    evaluation_strategy="epoch",
    logging_strategy="epoch",
    learning_rate=1e-4,
    num_train_epochs=8,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    output_dir=MODEL_DIR+'_EN',
    overwrite_output_dir=True,
    # The next line is important to ensure the dataset labels are properly passed to the model
    remove_unused_columns=False,
    save_total_limit=1,
)

# train_dataset.combine_with_another_dataset(valid_dataset)
# train_dataset = concatenate_datasets([dataset_en["train"], dataset_en["validation"]])

trainer = AdapterTrainer(
    model=model,
    args=training_args,
    train_dataset=en_train_dataset,
    eval_dataset=en_valid_dataset,
    compute_metrics=compute_metrics
)

trainer.add_callback(CustomCallback(trainer))

# %% [markdown]
# # Train

# %% [markdown]
# Start the training 🚀 (this will take a while)

# %%
train_result = trainer.train()

metrics = train_result.metrics
trainer.log_metrics("train_log", metrics)
trainer.save_metrics("train_log", metrics)
# Out:
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 16002
#   Num Epochs = 8
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 8008
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
#     <div>
#
#       <progress value='8008' max='8008' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8008/8008 2:21:31, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy@en</th>
#       <th>F1@en</th>
#       <th>Precision@en</th>
#       <th>Recall@en</th>
#       <th>Loss@en</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.142913</td>
#       <td>0.666292</td>
#       <td>0.405626</td>
#       <td>0.587886</td>
#       <td>0.369481</td>
#       <td>1.142913</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.499200</td>
#       <td>1.217003</td>
#       <td>0.639729</td>
#       <td>0.356498</td>
#       <td>0.455179</td>
#       <td>0.343155</td>
#       <td>1.217003</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.499200</td>
#       <td>1.013399</td>
#       <td>0.693163</td>
#       <td>0.497340</td>
#       <td>0.613853</td>
#       <td>0.452546</td>
#       <td>1.013399</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.147900</td>
#       <td>1.156281</td>
#       <td>0.640962</td>
#       <td>0.393347</td>
#       <td>0.507080</td>
#       <td>0.376935</td>
#       <td>1.156281</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.147900</td>
#       <td>0.939918</td>
#       <td>0.711161</td>
#       <td>0.539202</td>
#       <td>0.680612</td>
#       <td>0.487381</td>
#       <td>0.939918</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.058900</td>
#       <td>1.127922</td>
#       <td>0.648982</td>
#       <td>0.411370</td>
#       <td>0.519006</td>
#       <td>0.387387</td>
#       <td>1.127922</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.058900</td>
#       <td>0.893095</td>
#       <td>0.721097</td>
#       <td>0.560643</td>
#       <td>0.675166</td>
#       <td>0.523437</td>
#       <td>0.893095</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.003100</td>
#       <td>1.117406</td>
#       <td>0.644047</td>
#       <td>0.423850</td>
#       <td>0.516965</td>
#       <td>0.410364</td>
#       <td>1.117406</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.003100</td>
#       <td>0.859717</td>
#       <td>0.730784</td>
#       <td>0.577811</td>
#       <td>0.728424</td>
#       <td>0.518424</td>
#       <td>0.859717</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.954500</td>
#       <td>1.115760</td>
#       <td>0.653917</td>
#       <td>0.425713</td>
#       <td>0.537833</td>
#       <td>0.393541</td>
#       <td>1.115760</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.954500</td>
#       <td>0.819975</td>
#       <td>0.741970</td>
#       <td>0.604346</td>
#       <td>0.723414</td>
#       <td>0.547990</td>
#       <td>0.819975</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.917800</td>
#       <td>1.112933</td>
#       <td>0.656385</td>
#       <td>0.455976</td>
#       <td>0.564907</td>
#       <td>0.430670</td>
#       <td>1.112933</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.917800</td>
#       <td>0.802376</td>
#       <td>0.746469</td>
#       <td>0.608815</td>
#       <td>0.713815</td>
#       <td>0.559840</td>
#       <td>0.802376</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.886300</td>
#       <td>1.129995</td>
#       <td>0.661937</td>
#       <td>0.464167</td>
#       <td>0.551372</td>
#       <td>0.439397</td>
#       <td>1.129995</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.886300</td>
#       <td>0.791834</td>
#       <td>0.749156</td>
#       <td>0.614732</td>
#       <td>0.720478</td>
#       <td>0.562372</td>
#       <td>0.791834</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.867900</td>
#       <td>1.123586</td>
#       <td>0.658853</td>
#       <td>0.461021</td>
#       <td>0.556542</td>
#       <td>0.434088</td>
#       <td>1.123586</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-500
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-500/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-500/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-500/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-500/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-500/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-500/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-500/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-500/disrpt/pytorch_model_head.bin
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1000
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1000/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1000/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1000/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1000/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1000/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1000/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1000/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1000/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 16002
#   Batch size = 16
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** Running Evaluation *****
#   Num examples = 1621
#   Batch size = 16
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1500
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1500/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1500/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1500/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1500/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1500/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1500/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1500/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1500/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2000
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2000/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2000/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2000/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2000/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2000/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2000/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2000/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2000/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-1500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 16002
#   Batch size = 16
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** Running Evaluation *****
#   Num examples = 1621
#   Batch size = 16
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2500
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2500/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2500/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2500/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2500/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2500/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2500/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2500/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2500/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2000] due to args.save_total_limit
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3000
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3000/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3000/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3000/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3000/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3000/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3000/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3000/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3000/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-2500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 16002
#   Batch size = 16
# ***** Running Evaluation *****
#   Num examples = 1621
#   Batch size = 16
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3500
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3500/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3500/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3500/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3500/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3500/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3500/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3500/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3500/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4000
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4000/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4000/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4000/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4000/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4000/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4000/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4000/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4000/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-3500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 16002
#   Batch size = 16
# ***** Running Evaluation *****
#   Num examples = 1621
#   Batch size = 16
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4500
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4500/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4500/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4500/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4500/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4500/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4500/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4500/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4500/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4000] due to args.save_total_limit
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5000
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5000/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5000/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5000/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5000/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5000/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5000/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5000/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5000/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-4500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 16002
#   Batch size = 16
# ***** Running Evaluation *****
#   Num examples = 1621
#   Batch size = 16
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5500
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5500/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5500/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5500/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5500/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5500/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5500/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5500/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5500/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5000] due to args.save_total_limit
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6000
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6000/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6000/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6000/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6000/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6000/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6000/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6000/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6000/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-5500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 16002
#   Batch size = 16
# ***** Running Evaluation *****
#   Num examples = 1621
#   Batch size = 16
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6500
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6500/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6500/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6500/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6500/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6500/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6500/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6500/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6500/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6000] due to args.save_total_limit
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7000
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7000/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7000/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7000/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7000/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7000/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7000/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7000/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7000/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-6500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 16002
#   Batch size = 16
# ***** Running Evaluation *****
#   Num examples = 1621
#   Batch size = 16
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7500
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7500/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7500/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7500/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7500/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7500/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7500/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7500/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7500/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7000] due to args.save_total_limit
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-8000
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-8000/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-8000/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-8000/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-8000/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-8000/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-8000/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-8000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-8000/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-8000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-8000/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_EN/checkpoint-7500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 16002
#   Batch size = 16
# ***** Running Evaluation *****
#   Num examples = 1621
#   Batch size = 16
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# ***** train_log metrics *****
#   epoch                    =        8.0
#   total_flos               = 37331542GF
#   train_loss               =     1.0419
#   train_runtime            = 2:21:33.28
#   train_samples_per_second =     15.073
#   train_steps_per_second   =      0.943

# %%
# eval_trainer = AdapterTrainer(
#     model=model,
#     args=TrainingArguments(output_dir="./eval_output_en", remove_unused_columns=False,),
#     eval_dataset=en_test_dataset,
#     compute_metrics=compute_metrics,
# )
trainer.evaluate(metric_key_prefix='test_en',
                eval_dataset=en_test_dataset)
# Out:
# ***** Running Evaluation *****
#   Num examples = 2155
#   Batch size = 16
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 00:45]
#     </div>
# {'test_en_loss': 1.20975661277771,
#  'test_en_accuracy@en': 0.6580046403712297,
#  'test_en_f1@en': 0.4881558886369518,
#  'test_en_precision@en': 0.5719035643638274,
#  'test_en_recall@en': 0.45642819587598726,
#  'test_en_loss@en': 1.20975661277771,
#  'test_en_runtime': 45.5675,
#  'test_en_samples_per_second': 47.292,
#  'test_en_steps_per_second': 2.963,
#  'epoch': 8.0}

# %% [markdown]
# ## Cross-lingual transfer
#
# With the model and all adapters trained and ready, we can come to the cross-lingual transfer step here. We will evaluate our setup on the Chinese split of the XCOPA dataset.
# Therefore, we'll first download the data and preprocess it using the same method as the English dataset:

# %% [markdown]
# Next, let's adapt our setup to the new language. We simply replace the English language adapter with the Chinese language adapter we already loaded previously. The task adapter we just trained is kept. Again, we set this architecture using `active_adapters`:

# %%
lang = 'de'
model.active_adapters = Stack(lang, "disrpt")

# %% [markdown]
# Finally, let's see how well our adapter setup performs on the new language. We measure the zero-shot accuracy on the test split of the target language dataset. Evaluation is also performed using the built-in `Trainer` class.

# %% [markdown]
# ### Set training args for de

# %%
training_args = TrainingArguments(
    evaluation_strategy="epoch",
    logging_strategy="epoch",
    learning_rate=1e-4,
    num_train_epochs=8,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    output_dir=MODEL_DIR+'_DE',
    overwrite_output_dir=False,
    # The next line is important to ensure the dataset labels are properly passed to the model
    remove_unused_columns=False,
    save_total_limit=1,
    # resume_from_checkpoint=MODEL_DIR+'/last-checkpoint',
)

trainer = AdapterTrainer(
    model=model,
    args=training_args,
    train_dataset=de_train_dataset,
    eval_dataset=de_valid_dataset,
    compute_metrics=compute_metrics
)

trainer.add_callback(CustomCallback(trainer))
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
trainer.train()

metrics = train_result.metrics
trainer.log_metrics("train_logger", metrics)
trainer.save_metrics("train_logger", metrics)
# Out:
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 2164
#   Num Epochs = 8
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 2168
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
#     <div>
#
#       <progress value='2168' max='2168' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2168/2168 20:31, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy@de</th>
#       <th>F1@de</th>
#       <th>Precision@de</th>
#       <th>Recall@de</th>
#       <th>Loss@de</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>2.225829</td>
#       <td>0.350277</td>
#       <td>0.228179</td>
#       <td>0.275031</td>
#       <td>0.253067</td>
#       <td>2.225829</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.741200</td>
#       <td>2.445551</td>
#       <td>0.331950</td>
#       <td>0.205794</td>
#       <td>0.249839</td>
#       <td>0.246427</td>
#       <td>2.445552</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.741200</td>
#       <td>1.953777</td>
#       <td>0.425601</td>
#       <td>0.309457</td>
#       <td>0.354098</td>
#       <td>0.323060</td>
#       <td>1.953777</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.265700</td>
#       <td>2.291186</td>
#       <td>0.360996</td>
#       <td>0.256613</td>
#       <td>0.261596</td>
#       <td>0.274415</td>
#       <td>2.291186</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.265700</td>
#       <td>1.808799</td>
#       <td>0.455176</td>
#       <td>0.324228</td>
#       <td>0.345672</td>
#       <td>0.354156</td>
#       <td>1.808799</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.074600</td>
#       <td>2.268173</td>
#       <td>0.344398</td>
#       <td>0.236176</td>
#       <td>0.235492</td>
#       <td>0.267678</td>
#       <td>2.268173</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.074600</td>
#       <td>1.698839</td>
#       <td>0.471349</td>
#       <td>0.339613</td>
#       <td>0.397413</td>
#       <td>0.355348</td>
#       <td>1.698839</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.951100</td>
#       <td>2.294407</td>
#       <td>0.327801</td>
#       <td>0.237641</td>
#       <td>0.237618</td>
#       <td>0.260488</td>
#       <td>2.294407</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.951100</td>
#       <td>1.599388</td>
#       <td>0.507394</td>
#       <td>0.385863</td>
#       <td>0.398206</td>
#       <td>0.406357</td>
#       <td>1.599388</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.854400</td>
#       <td>2.266076</td>
#       <td>0.373444</td>
#       <td>0.258835</td>
#       <td>0.261072</td>
#       <td>0.288853</td>
#       <td>2.266076</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.854400</td>
#       <td>1.536510</td>
#       <td>0.521719</td>
#       <td>0.400867</td>
#       <td>0.423238</td>
#       <td>0.419571</td>
#       <td>1.536510</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.766100</td>
#       <td>2.279605</td>
#       <td>0.356846</td>
#       <td>0.239148</td>
#       <td>0.239120</td>
#       <td>0.270782</td>
#       <td>2.279605</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.766100</td>
#       <td>1.484770</td>
#       <td>0.549908</td>
#       <td>0.422601</td>
#       <td>0.434718</td>
#       <td>0.440597</td>
#       <td>1.484770</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.698300</td>
#       <td>2.281409</td>
#       <td>0.344398</td>
#       <td>0.245573</td>
#       <td>0.238718</td>
#       <td>0.270976</td>
#       <td>2.281409</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.698300</td>
#       <td>1.466999</td>
#       <td>0.548521</td>
#       <td>0.432601</td>
#       <td>0.485697</td>
#       <td>0.446654</td>
#       <td>1.466999</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.643700</td>
#       <td>2.279293</td>
#       <td>0.360996</td>
#       <td>0.241347</td>
#       <td>0.232254</td>
#       <td>0.268853</td>
#       <td>2.279293</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 2164
#   Batch size = 8
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** Running Evaluation *****
#   Num examples = 241
#   Batch size = 8
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-500
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-500/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-500/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-500/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-500/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-500/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-500/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-500/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-500/disrpt/pytorch_model_head.bin
# ***** Running Evaluation *****
#   Num examples = 2164
#   Batch size = 8
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** Running Evaluation *****
#   Num examples = 241
#   Batch size = 8
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** Running Evaluation *****
#   Num examples = 2164
#   Batch size = 8
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** Running Evaluation *****
#   Num examples = 241
#   Batch size = 8
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1000
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1000/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1000/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1000/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1000/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1000/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1000/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1000/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1000/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2164
#   Batch size = 8
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** Running Evaluation *****
#   Num examples = 241
#   Batch size = 8
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** Running Evaluation *****
#   Num examples = 2164
#   Batch size = 8
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** Running Evaluation *****
#   Num examples = 241
#   Batch size = 8
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1500
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1500/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1500/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1500/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1500/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1500/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1500/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1500/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1500/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1500/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2164
#   Batch size = 8
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** Running Evaluation *****
#   Num examples = 241
#   Batch size = 8
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** Running Evaluation *****
#   Num examples = 2164
#   Batch size = 8
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** Running Evaluation *****
#   Num examples = 241
#   Batch size = 8
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Saving model checkpoint to AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-2000
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-2000/en/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-2000/en/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-2000/de/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-2000/de/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-2000/disrpt/adapter_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-2000/disrpt/pytorch_adapter.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-2000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-2000/disrpt/pytorch_model_head.bin
# Configuration saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-2000/disrpt/head_config.json
# Module weights saved in AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-2000/disrpt/pytorch_model_head.bin
# Deleting older checkpoint [AdapterAlpha_lr=AdafactorDefault_plm=bert-base-multilingual-cased_Info=v3_lrtest1_DE/checkpoint-1500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2164
#   Batch size = 8
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ***** Running Evaluation *****
#   Num examples = 241
#   Batch size = 8
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# ***** train_logger metrics *****
#   epoch                    =        8.0
#   total_flos               = 37331542GF
#   train_loss               =     1.0419
#   train_runtime            = 2:21:33.28
#   train_samples_per_second =     15.073
#   train_steps_per_second   =      0.943

# %%
trainer.evaluate(metric_key_prefix='test_de',
                eval_dataset=de_test_dataset)
# Out:
# ***** Running Evaluation *****
#   Num examples = 260
#   Batch size = 8
#     <div>
#
#       <progress value='303' max='33' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [33/33 00:35]
#     </div>
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'test_de_loss': 2.554270029067993,
#  'test_de_accuracy@de': 0.25384615384615383,
#  'test_de_f1@de': 0.1910287697443995,
#  'test_de_precision@de': 0.1876885104298849,
#  'test_de_recall@de': 0.22257923190174714,
#  'test_de_loss@de': 2.554269790649414,
#  'test_de_runtime': 5.6729,
#  'test_de_samples_per_second': 45.832,
#  'test_de_steps_per_second': 5.817,
#  'epoch': 8.0}

# %%
lang = 'en(de)'

trainer.evaluate(metric_key_prefix='test_en(de)',
                eval_dataset=en_test_dataset)
# Out:
# ***** Running Evaluation *****
#   Num examples = 2155
#   Batch size = 8
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'test_en(de)_loss': 3.063689947128296,
#  'test_en(de)_accuracy@en(de)': 0.19443155452436195,
#  'test_en(de)_f1@en(de)': 0.08780287265168876,
#  'test_en(de)_precision@en(de)': 0.14753135317786634,
#  'test_en(de)_recall@en(de)': 0.0933562511176029,
#  'test_en(de)_loss@en(de)': 3.063689947128296,
#  'test_en(de)_runtime': 29.4497,
#  'test_en(de)_samples_per_second': 73.176,
#  'test_en(de)_steps_per_second': 9.168,
#  'epoch': 8.0}
# wandb: Network error (ReadTimeout), entering retry loop.
# wandb: ERROR Error while calling W&B API: internal database error (<Response [500]>)

# %% [markdown]
# You should get an overall accuracy of about 56 which is on-par with full finetuning on COPA only but below the state-of-the-art which is sequentially finetuned on an additional dataset before finetuning on COPA.
#
# For results on different languages and a sequential finetuning setup which yields better results, make sure to check out [the MAD-X paper](https://arxiv.org/pdf/2005.00052.pdf).

# %% [markdown]
# So you mean to say that even the SOTAs struggle to match randomized baseline for Zh.
