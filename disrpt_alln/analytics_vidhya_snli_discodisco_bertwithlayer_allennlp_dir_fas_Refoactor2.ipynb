# %%
#seeding for comparing experiment in part 2
import torch
import json
SEED = 1111
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

device = torch.device('cuda:2')

# %% [markdown]
# # SNLI Bert
# ## Second Tutorial
# https://towardsdatascience.com/fine-tuning-pre-trained-transformer-models-for-sentence-entailment-d87caf9ec9db
# Check his Github code for complete notebook. I never referred to it. Medium was enough.
# BERT in keras-tf: https://towardsdatascience.com/bert-in-keras-with-tensorflow-hub-76bcbc9417b

# %%
# define macros
BERT_MODEL = 'HooshvareLab/bert-fa-base-uncased' #'GroNLP/bert-base-dutch-cased'
# 'bert-base-multilingual-cased'
# 'bert-base-uncased'

batch_size = 4
batches_per_epoch = 402

# %% [markdown]
# # Prepare data

# %% [markdown]
# ## load the dataset

# %%
# !wget https://nlp.stanford.edu/projects/snli/snli_1.0.zip

# %%
import pandas as pd

# custom reader needed to handle quotechars
def read_df_custom(file):
    header = 'doc     unit1_toks      unit2_toks      unit1_txt       unit2_txt       s1_toks s2_toks unit1_sent      unit2_sent      dir     nuc_children    sat_children    genre   u1_discontinuous        u2_discontinuous       u1_issent        u2_issent       u1_length       u2_length       length_ratio    u1_speaker      u2_speaker      same_speaker    u1_func u1_pos  u1_depdir       u2_func u2_pos  u2_depdir       doclen  u1_position      u2_position     percent_distance        distance        lex_overlap_words       lex_overlap_length      unit1_case      unit2_case      label'
    header = header.split()
    df = pd.DataFrame(columns=['unit1_txt', 'unit1_sent', 'unit2_txt', 'unit2_sent', 'dir', 'label'])
    file = open(file, 'r')

    rows = []
    count = 0 
    for line in file:
        line = line[:-1].split('\t')
        count+=1
        if count ==1: continue
        row = {}
        for column in ['unit1_txt', 'unit1_sent', 'unit2_txt', 'unit2_sent', 'dir', 'label']:
            index = header.index(column)
            row[column] = line[index]
        rows.append(row)

    df = pd.concat([df, pd.DataFrame.from_records(rows)])
    return df

# we only need specific columns
# train_df = read_df_custom('../processed/nld.rst.nldt_train_enriched.rels')
# test_df = read_df_custom('../processed/nld.rst.nldt_test_enriched.rels')
# val_df = read_df_custom('../processed/nld.rst.nldt_dev_enriched.rels')
train_df = read_df_custom('../processed/fas.rst.prstc_train_enriched.rels')
test_df = read_df_custom('../processed/fas.rst.prstc_test_enriched.rels')
val_df = read_df_custom('../processed/fas.rst.prstc_dev_enriched.rels')
# train_df = read_df_custom('../processed/zho.rst.sctb_train_enriched.rels') #.tsv2
# test_df = read_df_custom('../processed/zho.rst.sctb_test_enriched.rels')
# val_df = read_df_custom('../processed/zho.rst.sctb_dev_enriched.rels')

# %% [markdown]
# ## Clean the data

# %%
#dropping any empty values
train_df.dropna(inplace=True)
val_df.dropna(inplace=True)
test_df.dropna(inplace=True)

# train_df = train_df[:500]
# val_df = val_df[:50]
# test_df = test_df[:50]

# %% [markdown]
# ## Prepare a dataset handler class

# %%
import torch
from torch.utils.data import Dataset, TensorDataset, DataLoader
from sys import path
path.append('/home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/allennlp/data/data_loaders/')
from allennlp.data import allennlp_collate#, DataLoader
# from allennlp.data.data_loaders.simple_data_loader import SimpleDataLoader
from torch.nn.utils.rnn import pad_sequence
from transformers import BertTokenizer
import pandas as pd

class MNLIDataBert(Dataset):

  def __init__(self, train_df, val_df, test_df):
    self.num_labels = -1
    self.train_df = train_df
    self.val_df = val_df
    self.test_df = test_df

    self.tokenizer = BertTokenizer.from_pretrained(BERT_MODEL, do_lower_case=True) # Using a pre-trained BERT tokenizer to encode sentences
    self.train_data = None
    self.val_data = None
    self.test_data = None
    self.train_idx = None
    self.val_idx = None
    self.test_idx = None
    self.init_data()

  def init_data(self):
    self.get_label_mapping()
    self.train_data, self.train_idx = self.load_data(self.train_df)
    self.val_data, self.val_idx = self.load_data(self.val_df)
    self.test_data, self.test_idx = self.load_data(self.test_df)

  def get_label_mapping(self):
    labels = {}
    labels_list = list(set(list(self.train_df['label'].unique()) + list(self.test_df['label'].unique()) + list(self.val_df['label'].unique())))
    for i in range(len(labels_list)):
        labels[labels_list[i]] = i
    self.label_dict = labels# {'entailment': 0, 'contradiction': 1, 'neutral': 2}
    # needed later for classification report object to generate precision and recall on test dataset
    self.rev_label_dict = {self.label_dict[k]:k for k in self.label_dict.keys()} 
  
  def add_directionality(self, premise, hypothesis, dir):
    if dir == "1<2":
        # hypothesis = '< ' + hypothesis + ' {'
        hypothesis = hypothesis + ' right'
    else:
        # premise = '} ' + premise + ' >'
        premise = 'left ' + premise
    return premise, hypothesis


  def load_data2(self, df):
    MAX_LEN = 256 # dont need to enforce this now because snli is a sanitized dataset where sentence lenghts are reasonable. otherwise the beert model doesn't have enough parameters to handle long length sentences
    token_ids = []
    mask_ids = []
    seg_ids = []
    y = []
    idx = []
    idx_map = {}
    # self.reach = 'reach'

    premise_list = df['unit1_txt'].to_list()
    hypothesis_list = df['unit2_txt'].to_list()
    label_list = df['label'].to_list()
    dir_list = df['dir'].to_list()
    
    self.num_labels = max(self.num_labels, len(df['label'].unique()))

    count=0
    for (premise, hypothesis, label, dir) in zip(premise_list, hypothesis_list, label_list, dir_list):
      print('old: ', premise, hypothesis)
      premise, hypothesis = self.add_directionality(premise, hypothesis, dir)
      print('new:', premise, hypothesis, '\n')
    

  def load_data(self, df):
    MAX_LEN = 256 # dont need to enforce this now because snli is a sanitized dataset where sentence lenghts are reasonable. otherwise the beert model doesn't have enough parameters to handle long length sentences
    token_ids = []
    mask_ids = []
    seg_ids = []
    y = []
    idx = []
    idx_map = {}
    # self.reach = 'reach'

    premise_list = df['unit1_txt'].to_list()
    hypothesis_list = df['unit2_txt'].to_list()
    label_list = df['label'].to_list()
    dir_list = df['dir'].to_list()
    
    self.num_labels = max(self.num_labels, len(df['label'].unique()))

    count=0
    for (premise, hypothesis, label, dir) in zip(premise_list, hypothesis_list, label_list, dir_list):
      premise, hypothesis = self.add_directionality(premise, hypothesis, dir)
      premise_id = self.tokenizer.encode(premise, add_special_tokens = False, max_length=MAX_LEN, truncation=True)
      print(premise)
      print(premise_id)
      # print(self.tokenizer.encode("< "))
      # print(self.tokenizer.encode("< this"))
      # print(self.tokenizer.encode("this ."))
      # print(self.tokenizer.encode("this } "))
      # print(self.tokenizer.encode("fffffff } "))
      hypothesis_id = self.tokenizer.encode(hypothesis, add_special_tokens = False, max_length=MAX_LEN, truncation=True)
      pair_token_ids = [self.tokenizer.cls_token_id] + premise_id + [self.tokenizer.sep_token_id] + hypothesis_id + [self.tokenizer.sep_token_id]
      premise_len = len(premise_id)
      hypothesis_len = len(hypothesis_id)

      segment_ids = torch.tensor([0] * (premise_len + 2) + [1] * (hypothesis_len + 1))  # sentence 0 and sentence 1
      attention_mask_ids = torch.tensor([1] * (premise_len + hypothesis_len + 3))  # mask padded values

      token_ids.append(torch.tensor(pair_token_ids))
      seg_ids.append(segment_ids)
      mask_ids.append(attention_mask_ids)
      y.append(self.label_dict[label])

      idx_map[count] = [premise, hypothesis]
      idx.append(count)
      count+=1
    
    token_ids = pad_sequence(token_ids, batch_first=True)
    mask_ids = pad_sequence(mask_ids, batch_first=True)
    seg_ids = pad_sequence(seg_ids, batch_first=True)

    y = torch.tensor(y)
    idx = torch.tensor(idx)
    dataset = TensorDataset(token_ids, mask_ids, seg_ids, y, idx)
    return dataset, idx_map

  def get_data_loaders(self, batch_size=4, batches_per_epoch=402, shuffle=True): #1609 samples / 64:25=1600 / 402:4=1608
    train_loader_torch = DataLoader(
      self.train_data,
      shuffle=shuffle,
      batch_size=batch_size,
    )

    val_loader_torch = DataLoader(
      self.val_data,
      shuffle=shuffle,
      batch_size=batch_size,
    )

    test_loader_torch = DataLoader(
      self.test_data,
      shuffle=False,#shuffle,
      batch_size=batch_size,
    )
    
    train_loader = LoaderWrapper(train_loader_torch, n_step=batches_per_epoch)
    val_loader = LoaderWrapper(val_loader_torch, n_step=batches_per_epoch)
    test_loader = LoaderWrapper(test_loader_torch, n_step=batches_per_epoch)

    return train_loader, val_loader_torch, test_loader_torch

# %%
class LoaderWrapper:
    def __init__(self, loader, n_step):
        self.step = n_step
        self.idx = 0
        self.iter_loader = iter(loader)
        self.loader = loader
    
    def __iter__(self):
        return self

    def __len__(self):
        return self.step

    def __next__(self):
        # if reached number of steps desired, stop
        if self.idx == self.step:
            self.idx = 0
            raise StopIteration
        else:
            self.idx += 1
        # while True
        try:
            return next(self.iter_loader)
        except StopIteration:
            # reinstate iter_loader, then continue
            self.iter_loader = iter(self.loader)
            return next(self.iter_loader)

# %%
mnli_dataset = MNLIDataBert(train_df, val_df, test_df)

train_loader, val_loader, test_loader = mnli_dataset.get_data_loaders(batch_size=batch_size, batches_per_epoch=batches_per_epoch) #64X250
label_dict = mnli_dataset.label_dict # required by custom func to calculate accuracy, bert model
rev_label_dict = mnli_dataset.rev_label_dict # required by custom func to calculate accuracy
# Out:
# left آثار نظامیگنجوی تواناییهای منحصربهفردی دارد
# [46752, 3917, 4291, 42819, 2824, 10624, 28845, 2924]
# آثار نظامیگنجوی تواناییهای منحصربهفردی دارد
# [3917, 4291, 42819, 2824, 10624, 28845, 2924]
# که فراتر از مرزهای فرهنگیای میرود
# [2800, 7842, 2791, 8053, 4009, 2784, 4077]
# که فراتر از مرزهای فرهنگیای میرود
# [2800, 7842, 2791, 8053, 4009, 2784, 4077]
# left شفافیت مانند آزادی موازین دارد .
# [46752, 9302, 3331, 4880, 20286, 2924, 1012]
# من نه تنها به این طرح رای مثبت دادم ،
# [2842, 3254, 3327, 2789, 2802, 3512, 3537, 5048, 10315, 1348]
# left گاهی برخی با سواستفاده از واژه آزادی ، آزادی را قربانی میکنند .
# [46752, 4671, 3237, 2799, 33894, 2791, 5599, 4880, 1348, 4880, 2803, 6729, 3133, 1012]
# left اگر در آزادی بیان مصونیت پس از بیان وجود نداشته باشد ،
# [46752, 3064, 2786, 4880, 3533, 21115, 2965, 2791, 3533, 3022, 5102, 3048, 1348]
# یکی از لازمههای آزادی بیان آن است که آزادی پس از بیان وجود داشته باشد .
# [3036, 2791, 74522, 4880, 3533, 2808, 2806, 2800, 4880, 2965, 2791, 3533, 3022, 3151, 3048, 1012]
# یکی از لازمههای آزادی بیان آن است که آزادی پس از بیان وجود داشته باشد .
# [3036, 2791, 74522, 4880, 3533, 2808, 2806, 2800, 4880, 2965, 2791, 3533, 3022, 3151, 3048, 1012]
# شفافیت آرای نمایندگان نیز شرایطی مشابه آزادی بیان دارد .
# [9302, 9277, 5098, 2921, 5799, 4942, 4880, 3533, 2924, 1012]
# شفافیت نقطه کانونی گفتمان اصلاح طلبی است .
# [9302, 4832, 19643, 11067, 4055, 13893, 2806, 1012]
# شفافیت عناصر و شاخصههایی دارد
# [9302, 6573, 1379, 92782, 2924]
# که یکی از مهم ترین شاخصههای شفافیت ، گردش آزاد اطلاعات و دسترسی آزاد به اطلاعات است .
# [2800, 3036, 2791, 3337, 15407, 24566, 9302, 1348, 4057, 3912, 3531, 1379, 4825, 3912, 2789, 3531, 2806, 1012]
# دسترسی مردم به اطلاعات حق مردم است
# [4825, 3155, 2789, 3531, 3442, 3155, 2806]
# و سلب این حق نیازمند دلیل و برهان است
# [1379, 13184, 2802, 3442, 6137, 3310, 1379, 15029, 2806]
# که یکی از مهم ترین شاخصههای شفافیت ، گردش آزاد اطلاعات و دسترسی آزاد به اطلاعات است .
# [2800, 3036, 2791, 3337, 15407, 24566, 9302, 1348, 4057, 3912, 3531, 1379, 4825, 3912, 2789, 3531, 2806, 1012]
# من نه تنها به این طرح رای مثبت دادم ،
# [2842, 3254, 3327, 2789, 2802, 3512, 3537, 5048, 10315, 1348]
# مواردی که این روزها برای برخی نمایندگان نسبت به موضوع شفافیت طلبی در آرای نمایندگان تردید ایجاد کرده ، آن است که :
# [6316, 2800, 2802, 6577, 2831, 3237, 5098, 3368, 2789, 3444, 9302, 13893, 2786, 9277, 5098, 8333, 3280, 3027, 1348, 2808, 2806, 2800, 1014]
# left چرا یک نماینده باید از افشا شدن رای خود هراس داشته باشد ؟
# [46752, 3660, 2829, 4842, 3013, 2791, 11304, 3322, 3537, 2847, 13432, 3151, 3048, 1350]
# چرا یک نماینده باید از افشا شدن رای خود هراس داشته باشد ؟
# [3660, 2829, 4842, 3013, 2791, 11304, 3322, 3537, 2847, 13432, 3151, 3048, 1350]
# ۱ - باید قبل از شفافیت آرای نمایندگان ما مصونیت طلبی پس از رای را مطالبه کنیم .
# [1455, 1011, 3013, 3556, 2791, 9302, 9277, 5098, 2964, 21115, 13893, 2965, 2791, 3537, 2803, 12693, 3592, 1012]
# کسانی <*> باید به این سوال پاسخ دهند که چرا ساختار ما به گونهای است که نمایندگان از مشخص شدن رای خود هراس داشته باشند ؟
# [4499, 1016, 1008, 1018, 3013, 2789, 2802, 4639, 3905, 4577, 2800, 3660, 4856, 2964, 2789, 5793, 2806, 2800, 5098, 2791, 3684, 3322, 3537, 2847, 13432, 3151, 3689, 1350]
# ۱ - باید قبل از شفافیت آرای نمایندگان ما مصونیت طلبی پس از رای را مطالبه کنیم .
# [1455, 1011, 3013, 3556, 2791, 9302, 9277, 5098, 2964, 21115, 13893, 2965, 2791, 3537, 2803, 12693, 3592, 1012]
# ۲ - ما باید مصونیت یکسان داشته باشیم .
# [1456, 1011, 2964, 3013, 21115, 7396, 3151, 4793, 1012]
# left اگر طیفی در ساختار قدرت رویین تن نبوده
# [46752, 3064, 18864, 2786, 4856, 3661, 47869, 3033, 6504]
# اگر طیفی در ساختار قدرت رویین تن نبوده
# [3064, 18864, 2786, 4856, 3661, 47869, 3033, 6504]
# نباید طیفی از مجلس رویین تن باشند .
# [4719, 18864, 2791, 3590, 47869, 3033, 3689, 1012]
# حتما نمایندگان از این طرح استقبال خواهند کرد .
# [4567, 5098, 2791, 2802, 3512, 6055, 4564, 2830, 1012]
# مردم اکنون باید بدانند این تردیدی <*> ریشه در کجا دارد .
# [3155, 4281, 3013, 9752, 2802, 18263, 1016, 1008, 1018, 5782, 2786, 6807, 2924, 1012]
# left این تردید به آن دلیل است که عدهای در مناسبات قدرت رویین تن بوده
# [46752, 2802, 8333, 2789, 2808, 3310, 2806, 2800, 6416, 2786, 12321, 3661, 47869, 3033, 3225]
# عدهای در مناسبات قدرت رویین تن بوده
# [6416, 2786, 12321, 3661, 47869, 3033, 3225]
# این تردید به آن دلیل است که عدهای در مناسبات قدرت رویین تن بوده
# [2802, 8333, 2789, 2808, 3310, 2806, 2800, 6416, 2786, 12321, 3661, 47869, 3033, 3225]
# left به همین دلایل است که ما میگوییم
# [46752, 2789, 3241, 5495, 2806, 2800, 2964, 11286]
# مردم اکنون باید بدانند این تردیدی <*> ریشه در کجا دارد .
# [3155, 4281, 3013, 9752, 2802, 18263, 1016, 1008, 1018, 5782, 2786, 6807, 2924, 1012]
# من نه تنها به این طرح رای مثبت دادم ،
# [2842, 3254, 3327, 2789, 2802, 3512, 3537, 5048, 10315, 1348]
# شفافیت آرای نمایندگان یک مصداق از هزاران مصداق شفافیت است .
# [9302, 9277, 5098, 2829, 14221, 2791, 7579, 14221, 9302, 2806, 1012]
# دوستانی <*> اجازه دهند شفافیت در تمامی حوزههای قدرت انجام شود
# [21731, 1016, 1008, 1018, 4463, 4577, 9302, 2786, 4479, 7471, 3661, 3096, 3073]
# اجازه دهند شفافیت در تمامی حوزههای قدرت انجام شود
# [4463, 4577, 9302, 2786, 4479, 7471, 3661, 3096, 3073]
# [2786, 3677, 5799, 10837, 1016, 1008, 1018, 2831, 5960, 4072, 7959, 2847, 2789, 6807, 3013, 5563, 3168, 1350]
# دلیل این نقض حقوق خریدار توسط فروشنده ، ارتباط میان فروشنده با نهادهای قدرت است .
# [3310, 2802, 8157, 4072, 10837, 3158, 10327, 1348, 3490, 3273, 10327, 2799, 6701, 3661, 2806, 1012]
# بعضا هزینه پیگیری در کشور ما آنچنان زیاد است
# [10619, 4001, 5960, 2786, 2930, 2964, 12066, 4216, 2806]
# left یکی از موارد اساسی <*> آن است که حاکمیت قانون یک الزام باشد .
# [46752, 3036, 2791, 3907, 4664, 1016, 1008, 1018, 2808, 2806, 2800, 8161, 3632, 2829, 8266, 3048, 1012]
# یکی از موارد اساسی <*> آن است که حاکمیت قانون یک الزام باشد .
# [3036, 2791, 3907, 4664, 1016, 1008, 1018, 2808, 2806, 2800, 8161, 3632, 2829, 8266, 3048, 1012]
# از جمله نهادهایی <*> نهاد قانون است .
# [2791, 3525, 21828, 1016, 1008, 1018, 5151, 3632, 2806, 1012]
# در چنین شرایطی حقوق عموم مردم و طرفین قراردادهای مختلف تضمین میشود
# [2786, 3677, 5799, 4072, 5937, 3155, 1379, 9239, 7994, 3431, 7829, 2886]
# در چنین شرایطی حقوق عموم مردم و طرفین قراردادهای مختلف تضمین میشود
# [2786, 3677, 5799, 4072, 5937, 3155, 1379, 9239, 7994, 3431, 7829, 2886]
# درکنار این موارد ، همزمان شاهد نقض مالکیت مردم توسط دولتها هستیم .
# [26844, 2802, 3907, 1348, 4780, 4426, 8157, 7959, 3155, 3158, 9139, 4590, 1012]
# یکی از مواردی <*> مبادرت دولت به کاهش ارزش پول ملی است
# [3036, 2791, 6316, 1016, 1008, 1018, 17186, 3099, 2789, 3300, 4007, 3928, 3333, 2806]
# در چنین شرایطی حقوق عموم مردم و طرفین قراردادهای مختلف تضمین میشود
# [2786, 3677, 5799, 4072, 5937, 3155, 1379, 9239, 7994, 3431, 7829, 2886]
# بنابراین آنچه توسط برخی دولتمردان نهادگرا عنوان میشود دارای مولفههایی است
# [3882, 4420, 3158, 3237, 13312, 5151, 6426, 3014, 2886, 3450, 45275, 2806]
# بنابراین آنچه توسط برخی دولتمردان نهادگرا عنوان میشود دارای مولفههایی است
# [3882, 4420, 3158, 3237, 13312, 5151, 6426, 3014, 2886, 3450, 45275, 2806]
# left اگر به این مولفه توجه شده
# [46752, 3064, 2789, 2802, 13310, 3211, 2871]
# اگر به این مولفه توجه شده
# [3064, 2789, 2802, 13310, 3211, 2871]
# نخستین مولفه حاکمیت قانون و دومین مولفه احترام به حقوق مالکیت است .
# [3923, 13310, 8161, 3632, 1379, 5196, 13310, 6755, 2789, 4072, 7959, 2806, 1012]
# left اما مادامی که ما شاهد نقض مکرر حاکمیت مردم و همچنین ناتوانی دستگاه قضایی در مقابله با این موارد <*> هستیم ،
# [46752, 2949, 26385, 2800, 2964, 4426, 8157, 10046, 8161, 3155, 1379, 3111, 11277, 3698, 5975, 2786, 5824, 2799, 2802, 3907, 1016, 1008, 1018, 4590, 1348]
# left به دلیل گستردگی و شدت
# [46752, 2789, 3310, 15342, 1379, 4931]
# نهادگرایی گسترش پیدا خواهد کرد
# [86096, 4554, 3510, 3201, 2830]
# left دراین میان صحبت از بازار آزاد فرصتی را برای صاحبان ثروت فراهم میکند
# [46752, 9111, 3273, 4386, 2791, 3179, 3912, 9455, 2803, 2831, 9075, 6044, 4319, 2980]
# دراین میان صحبت از بازار آزاد فرصتی را برای صاحبان ثروت فراهم میکند
# [9111, 3273, 4386, 2791, 3179, 3912, 9455, 2803, 2831, 9075, 6044, 4319, 2980]
# دراین میان صحبت از بازار آزاد فرصتی را برای صاحبان ثروت فراهم میکند
# [9111, 3273, 4386, 2791, 3179, 3912, 9455, 2803, 2831, 9075, 6044, 4319, 2980]
# این اتفاقی است که به کرات در ایران رخ داده
# [2802, 7082, 2806, 2800, 2789, 15776, 2786, 2927, 4440, 3171]
# اقتصاد هر کشوری برای کارکرد مناسب نیازمند نهادهای مختلف است
# [3563, 2937, 5973, 2831, 7775, 4006, 6137, 6701, 3431, 2806]
# بنابراین خلا نهادی <*> احساس میشود .
# [3882, 5515, 13460, 1016, 1008, 1018, 4189, 2886, 1012]
# بنابراین خلا نهادی <*> احساس میشود .
# [3882, 5515, 13460, 1016, 1008, 1018, 4189, 2886, 1012]
# به بیان دیگر نهادی <*> وجود ندارد .
# [2789, 3533, 2972, 13460, 1016, 1008, 1018, 3022, 3644, 1012]
# بنابراین خلا نهادی <*> احساس میشود .
# [3882, 5515, 13460, 1016, 1008, 1018, 4189, 2886, 1012]
# مطرح شدن موضوع بازنگری در ساختار اقتصادی ، بحث تازهای نیست .
# [4084, 3322, 3444, 10758, 2786, 4856, 3433, 1348, 4316, 9451, 3152, 1012]
# در سه دهه گذشته ما همواره شاهد حضور سیاستهایی به اسم بازار آزاد بودیم
# [2786, 3140, 4194, 3421, 2964, 5293, 4426, 3470, 22782, 2789, 4907, 3179, 3912, 6423]
# و این سیاستها در شرایطی پدیدار میشدند
# [1379, 2802, 11934, 2786, 5799, 8221, 6199]
# که بستر نهادی تحقق بازار آزاد وجود نداشت .
# [2800, 7362, 13460, 6435, 3179, 3912, 3022, 4379, 1012]
# در آن دوران اقداماتی صورت گرفت
# [2786, 2808, 3775, 9606, 3080, 3153]
# در آن دوران اقداماتی صورت گرفت
# [2786, 2808, 3775, 9606, 3080, 3153]
# و این تامین منافع ، سبب بروز شکاف طبقاتی ، اختلاف درآمدی و از دست رفتن فرصتهای اجتماعی برای جمعیت کثیری از مردم شد .
# [1379, 2802, 3823, 6398, 1348, 4829, 5015, 8882, 15213, 1348, 5086, 11656, 1379, 2791, 2910, 5200, 9347, 3614, 2831, 4172, 20507, 2791, 3155, 2817, 1012]
# خروجی دیگر این دیدگاه ، فقر بیش از حد مردم بود .
# [6945, 2972, 2802, 5984, 1348, 8112, 3385, 2791, 4253, 3155, 2834, 1012]
# خروجی دیگر این دیدگاه ، فقر بیش از حد مردم بود .
# [6945, 2972, 2802, 5984, 1348, 8112, 3385, 2791, 4253, 3155, 2834, 1012]
# مصداق یکی از ناامنیهای موجود در کشور گله مندی مردم از رفتار دیگر شهروندان است
# [14221, 3036, 2791, 60907, 3731, 2786, 2930, 12607, 15293, 3155, 2791, 4656, 2972, 6788, 2806]
# left ما برای آنکه بتوانیم یک اقتصاد سالم داشته باشیم ،
# [46752, 2964, 2831, 4695, 7779, 2829, 3563, 5644, 3151, 4793, 1348]
# مطرح شدن موضوع بازنگری در ساختار اقتصادی ، بحث تازهای نیست .
# [4084, 3322, 3444, 10758, 2786, 4856, 3433, 1348, 4316, 9451, 3152, 1012]
# left در اقتصاد سالم ، مهم ترین کارکرد عبارت است از اعتماد عمومیبه ساختار اقتصادی .
# [46752, 2786, 3563, 5644, 1348, 3337, 15407, 7775, 4226, 2806, 2791, 5040, 3885, 2954, 4856, 3433, 1012]
# در اقتصاد سالم ، مهم ترین کارکرد عبارت است از اعتماد عمومیبه ساختار اقتصادی .
# [2786, 3563, 5644, 1348, 3337, 15407, 7775, 4226, 2806, 2791, 5040, 3885, 2954, 4856, 3433, 1012]
# نیازمند کارکرد نهادهای اصلی و اساسی برای کارکردهای اقتصادی هستیم .
# [6137, 7775, 6701, 3376, 1379, 4664, 2831, 17253, 3433, 4590, 1012]
# و این مولفه مهم همان سرمایه اجتماعی است .
# [1379, 2802, 13310, 3337, 3413, 3497, 3614, 2806, 1012]
# سرمایهای که در سه دهه گذشته <*> به شدت آسیب دیده است
# [14147, 2800, 2786, 3140, 4194, 3421, 1016, 1008, 1018, 2789, 4931, 4532, 4275, 2806]
# سرمایهای که در سه دهه گذشته <*> به شدت آسیب دیده است
# [14147, 2800, 2786, 3140, 4194, 3421, 1016, 1008, 1018, 2789, 4931, 4532, 4275, 2806]
# left برای بازسازی این سرمایه آسیب خورده
# [46752, 2831, 6225, 2802, 3497, 4532, 7533]
# سرمایهای که در سه دهه گذشته <*> به شدت آسیب دیده است
# [14147, 2800, 2786, 3140, 4194, 3421, 1016, 1008, 1018, 2789, 4931, 4532, 4275, 2806]
# left و مادامی که این نهادها مستقر نشوند ،
# [46752, 1379, 26385, 2800, 2802, 11743, 7650, 11357, 1348]
# نیازمند استقرار نهادها و ساختارهای نهادی متناسب هستیم
# [6137, 8504, 11743, 1379, 10399, 13460, 7523, 4590]
# نرخ ارز تحتتاثیر عوامل مختلفی قرار دارد
# [3849, 3359, 16235, 4998, 5042, 2959, 2924]
# که بدون دقت در آنها نمیتوانیم شرایط بازار و تغییرات یا التهابات ارزی را بررسی کنیم .
# [2800, 3557, 5884, 2786, 2950, 9990, 3517, 3179, 1379, 4995, 2880, 27279, 4728, 2803, 3640, 3592, 1012]
# left زمانی که نرخ ارز افزایش یافت ،
# [46752, 3594, 2800, 3849, 3359, 3191, 3545, 1348]
# نرخ ارز تحتتاثیر عوامل مختلفی قرار دارد
# [3849, 3359, 16235, 4998, 5042, 2959, 2924]
# حبابهای قیمتی در بخشهای مختلف ایجاد شد .
# [28975, 7189, 2786, 5085, 3431, 3280, 2817, 1012]
# اما با ورود نرخ ارز به کانال ١٢ و ١۳ هزار تومان ، قدری از حبابهای قیمتی تخلیه شد .
# [2949, 2799, 4247, 3849, 3359, 2789, 6386, 18728, 1379, 1383, 2043, 3245, 3832, 1348, 11053, 2791, 28975, 7189, 9222, 2817, 1012]
# از سوی دیگر تقاضا برای ارز و برخی کالاهای ارزبر نیز متعادل شد .
# [2791, 3523, 2972, 6499, 2831, 3359, 1379, 3237, 6565, 3359, 2905, 2921, 12274, 2817, 1012]
# left زمانی که نرخ بیش از اندازه افزایش یافت ،
# [46752, 3594, 2800, 3849, 3385, 2791, 4205, 3191, 3545, 1348]
# حبابهای قیمتی در بخشهای مختلف ایجاد شد .
# [28975, 7189, 2786, 5085, 3431, 3280, 2817, 1012]
# تقاضا برای برخی کالاهایی <*> تعدیل شد
# [6499, 2831, 3237, 16674, 1016, 1008, 1018, 10391, 2817]
# تقاضا برای برخی کالاهایی <*> تعدیل شد
# [6499, 2831, 3237, 16674, 1016, 1008, 1018, 10391, 2817]
# تقاضا برای برخی کالاهایی <*> تعدیل شد
# [6499, 2831, 3237, 16674, 1016, 1008, 1018, 10391, 2817]
# left طبعا وقتی رکود بر اقتصاد حاکم باشد
# [46752, 16625, 3711, 6355, 2801, 3563, 5030, 3048]
# اما وجود شرایط رکود تورمی بر اقتصاد نیز بر کاهش نرخ ارز بیتاثیر نبوده است .
# [2949, 3022, 3517, 6355, 14023, 2801, 3563, 2921, 2801, 3300, 3849, 3359, 27403, 6504, 2806, 1012]
# حبابهای قیمتی در بخشهای مختلف ایجاد شد .
# [28975, 7189, 2786, 5085, 3431, 3280, 2817, 1012]
# از سوی دیگر ، واقعی شدن نرخ ارز ، از هم گسیختگی در بازار ارز را کم کرد
# [2791, 3523, 2972, 1348, 4666, 3322, 3849, 3359, 1348, 2791, 2820, 33293, 2786, 3179, 3359, 2803, 2961, 2830]
# از سوی دیگر ، واقعی شدن نرخ ارز ، از هم گسیختگی در بازار ارز را کم کرد
# [2791, 3523, 2972, 1348, 4666, 3322, 3849, 3359, 1348, 2791, 2820, 33293, 2786, 3179, 3359, 2803, 2961, 2830]
# به عنوان مثال بسیاری از سفرهای دستگاههای اجرایی کاهش یافت .
# [2789, 3014, 4183, 3398, 2791, 8780, 5695, 4761, 3300, 3545, 1012]
# left اما نکته مهمی <*> اهتمام بانک مرکزی بود به کنترل ارز .
# [46752, 2949, 4909, 5289, 1016, 1008, 1018, 14287, 3227, 3712, 2834, 2789, 3948, 3359, 1012]
# اما نکته مهمی <*> اهتمام بانک مرکزی بود به کنترل ارز .
# [2949, 4909, 5289, 1016, 1008, 1018, 14287, 3227, 3712, 2834, 2789, 3948, 3359, 1012]
# اما نکته مهمی <*> اهتمام بانک مرکزی بود به کنترل ارز .
# [2949, 4909, 5289, 1016, 1008, 1018, 14287, 3227, 3712, 2834, 2789, 3948, 3359, 1012]
# رییس کل بانک مرکزی ، جناب همتی بارها از مدیریت نوسانهای ارز توسط سیاستهای ارزی سخن گفتند
# [4800, 3142, 3227, 3712, 1348, 11406, 18526, 6322, 2791, 3916, 29835, 3359, 3158, 5242, 4728, 4402, 7294]
# رییس کل بانک مرکزی ، جناب همتی بارها از مدیریت نوسانهای ارز توسط سیاستهای ارزی سخن گفتند
# [4800, 3142, 3227, 3712, 1348, 11406, 18526, 6322, 2791, 3916, 29835, 3359, 3158, 5242, 4728, 4402, 7294]
# حبابهای قیمتی در بخشهای مختلف ایجاد شد .
# [28975, 7189, 2786, 5085, 3431, 3280, 2817, 1012]
# حبابهای قیمتی در بخشهای مختلف ایجاد شد .
# [28975, 7189, 2786, 5085, 3431, 3280, 2817, 1012]
# تعدیل التهاب بازار ارز در کنار بهکارگیری مکانیزمهایی مانند بازار ثانویه و سامانه سنا به کاهش نرخ ارز کمک میکند .
# [10391, 9037, 3179, 3359, 2786, 3668, 13194, 62694, 3331, 3179, 12042, 1379, 5740, 10827, 2789, 3300, 3849, 3359, 3469, 2980, 1012]
# رویکردها و بازارهای ارزی ، ما را به سمت بازار یکنواخت شدهای هدایت میکند
# [26602, 1379, 5616, 4728, 1348, 2964, 2803, 2789, 3757, 3179, 11996, 12809, 5587, 2980]
# تعدیل التهاب بازار ارز در کنار بهکارگیری مکانیزمهایی مانند بازار ثانویه و سامانه سنا به کاهش نرخ ارز کمک میکند .
# [10391, 9037, 3179, 3359, 2786, 3668, 13194, 62694, 3331, 3179, 12042, 1379, 5740, 10827, 2789, 3300, 3849, 3359, 3469, 2980, 1012]
# اما نکته مهمی <*> استقلال بانک مرکزی است .
# [2949, 4909, 5289, 1016, 1008, 1018, 4885, 3227, 3712, 2806, 1012]
# تعدیل التهاب بازار ارز در کنار بهکارگیری مکانیزمهایی مانند بازار ثانویه و سامانه سنا به کاهش نرخ ارز کمک میکند .
# [10391, 9037, 3179, 3359, 2786, 3668, 13194, 62694, 3331, 3179, 12042, 1379, 5740, 10827, 2789, 3300, 3849, 3359, 3469, 2980, 1012]
# بعد از التهابهای ارزی بانک مرکزی توانست در سایه استقلال نسبی و عدم دخالت ارگانهای دولتی تصمیمگیریهای خوب و به دور از شرایط سیاسی اتخاذ کند
# [3082, 2791, 66723, 4728, 3227, 3712, 4542, 2786, 7561, 4885, 8052, 1379, 4248, 7648, 19113, 4433, 23746, 4124, 1379, 2789, 3021, 2791, 3517, 3654, 8050, 3054]
# نرخ ارز تحتتاثیر عوامل مختلفی قرار دارد
# [3849, 3359, 16235, 4998, 5042, 2959, 2924]
# فلذا ، با دقت و بررسی عواملی <*> میتوان نسبت به ادامه ثبات در بازار ارز خوشبین بود .
# [53489, 1348, 2799, 5884, 1379, 3640, 10762, 1016, 1008, 1018, 2944, 3368, 2789, 3251, 7011, 2786, 3179, 3359, 21637, 2834, 1012]
# left من منتقد رفتارها و برخوردهای خشن با دختران و زنان هستم
# [46752, 2842, 5733, 14442, 1379, 18226, 10192, 2799, 7752, 1379, 4039, 6794]
# left و به نظر م اینگونه برخوردها باعث نمیشود که زنان به حجاب روی بیاورند .
# [46752, 1379, 2789, 3138, 1376, 6194, 27350, 3457, 4684, 2800, 4039, 2789, 10072, 3040, 11866, 1012]
# من منتقد رفتارها و برخوردهای خشن با دختران و زنان هستم
# [2842, 5733, 14442, 1379, 18226, 10192, 2799, 7752, 1379, 4039, 6794]
# به عبارت دگیر این رفتارها دینی نیست .
# [2789, 4226, 50732, 2807, 2802, 14442, 6050, 3152, 1012]
# اسلام دین رحمت است
# [3272, 4929, 13823, 2806]
# و به مسلمانان امر نشده
# [1379, 2789, 6547, 4389, 4338]
# left البته باید این موضوع را بررسی کرد
# [46752, 3546, 3013, 2802, 3444, 2803, 3640, 2830]
# left و از وزیر کشور هم تشکر میکنیم
# [46752, 1379, 2791, 3646, 2930, 2820, 9093, 4279]
# و از وزیر کشور هم تشکر میکنیم
# [1379, 2791, 3646, 2930, 2820, 9093, 4279]
# و از وزیر کشور هم تشکر میکنیم
# [1379, 2791, 3646, 2930, 2820, 9093, 4279]
# left ابتدا باید ببینیم وزارت کشور چه اقدامی در این خصوص انجام میدهد
# [46752, 4309, 3013, 9706, 3586, 2930, 3051, 8813, 2786, 2802, 3519, 3096, 3238]
# ابتدا باید ببینیم وزارت کشور چه اقدامی در این خصوص انجام میدهد
# [4309, 3013, 9706, 3586, 2930, 3051, 8813, 2786, 2802, 3519, 3096, 3238]
# left گفتنی است که راهحل رفع خشونت علیه زنان در جامعه ، در لایحه امنیت خشونت در فضای عمومی نیز تعریف شده است .
# [46752, 10874, 2806, 2800, 11643, 5418, 6997, 4249, 4039, 2786, 3780, 1348, 2786, 7352, 4449, 6997, 2786, 4049, 3885, 2921, 4568, 2871, 2806, 1012]
# left این رفتارها خشونت در فضای عمومی هستند
# [46752, 2802, 14442, 6997, 2786, 4049, 3885, 3060]
# left و اگر در این لایحه هم موضوع خشونت علیه زنان دیده نشده باشد ،
# [46752, 1379, 3064, 2786, 2802, 7352, 2820, 3444, 6997, 4249, 4039, 4275, 4338, 3048, 1348]
# left میتوانیم بازنگری کنیم
# [46752, 6027, 10758, 3592]
# میتوانیم بازنگری کنیم
# [6027, 10758, 3592]
# میتوانیم بازنگری کنیم
# [6027, 10758, 3592]
# left با این اوصاف فکر نمیکنم که افراد جامعه ما شایسته برخورد به این شکل <*> باشند .
# [46752, 2799, 2802, 16662, 4031, 12417, 2800, 3440, 3780, 2964, 9687, 3878, 2789, 2802, 3499, 1016, 1008, 1018, 3689, 1012]
# با این اوصاف فکر نمیکنم که افراد جامعه ما شایسته برخورد به این شکل <*> باشند .
# [2799, 2802, 16662, 4031, 12417, 2800, 3440, 3780, 2964, 9687, 3878, 2789, 2802, 3499, 1016, 1008, 1018, 3689, 1012]
# میتوانیم بازنگری کنیم
# [6027, 10758, 3592]
# باید با افراد جامعه اعم از زن و مرد ، کودک و حتی با حیوانات با احترام رفتار کنیم .
# [3013, 2799, 3440, 3780, 9092, 2791, 4100, 1379, 2999, 1348, 4891, 1379, 3466, 2799, 6732, 2799, 6755, 4656, 3592, 1012]
# left در حال حاضر ضرورت تصویب قانون و الزام ماموران پلیس به نصب دوربین برای حمایت و حفاظت از حقوق شهروندان و حتی متهمان و مجرمان بیش از هر زمانی احساس میشود .
# [46752, 2786, 3035, 3802, 7109, 5012, 3632, 1379, 8266, 8502, 5103, 2789, 5596, 4834, 2831, 3876, 1379, 6186, 2791, 4072, 6788, 1379, 3466, 13838, 1379, 20023, 3385, 2791, 2937, 3594, 4189, 2886, 1012]
# left ما میبینیم دادستان تهران ، شهردار پایتخت را <*> بلافاصله ساعت ١۰ و ١١ شب فرا میخواند .
# [46752, 2964, 8700, 8548, 3326, 1348, 8486, 5566, 2803, 1016, 1008, 1018, 7856, 3551, 1383, 2058, 1379, 23447, 3256, 3695, 8928, 1012]
# به سبب این که در برنامه نمایشی یک سری دختر بچه حضور پیدا کرده
# [2789, 4829, 2802, 2800, 2786, 3329, 9992, 2829, 3593, 4714, 5991, 3470, 3510, 3027]
# به سبب این که در برنامه نمایشی یک سری دختر بچه حضور پیدا کرده
# [2789, 4829, 2802, 2800, 2786, 3329, 9992, 2829, 3593, 4714, 5991, 3470, 3510, 3027]
# ما میبینیم دادستان تهران ، شهردار پایتخت را <*> بلافاصله ساعت ١۰ و ١١ شب فرا میخواند .
# [2964, 8700, 8548, 3326, 1348, 8486, 5566, 2803, 1016, 1008, 1018, 7856, 3551, 1383, 2058, 1379, 23447, 3256, 3695, 8928, 1012]
# left در پی برگزاری مراسمی در یک مجتمع تجاری در مشهد
# [46752, 2786, 3063, 5003, 13191, 2786, 2829, 8948, 4545, 2786, 6187]
# left پس شما میبینید برخوردهای سلبی این چنینی خیلی سریع و فوری صورت میگیرد
# [46752, 2965, 3124, 8146, 18226, 30909, 2802, 21852, 3805, 4861, 1379, 10286, 3080, 3858]
# پس شما میبینید برخوردهای سلبی این چنینی خیلی سریع و فوری صورت میگیرد
# [2965, 3124, 8146, 18226, 30909, 2802, 21852, 3805, 4861, 1379, 10286, 3080, 3858]
# left گویی وقتی به مردم ظلم شود
# [46752, 9639, 3711, 2789, 3155, 12318, 3073]
# ولی در مقابله با خشونت روا شده با مردم ، میبینیم که روند برخورد کاملا تغییر میکند .
# [3362, 2786, 5824, 2799, 6997, 22953, 2871, 2799, 3155, 1348, 8700, 2800, 4393, 3878, 4335, 3320, 2980, 1012]
# left ما وزیر کشور را دیدیم که گفت
# [46752, 2964, 3646, 2930, 2803, 13615, 2800, 3017]
# left برخورد میکند
# [46752, 3878, 2980]
# left و خانم دکتر ابتکار هم گفت
# [46752, 1379, 6145, 4283, 10077, 2820, 3017]
# برخورد میکند
# [3878, 2980]
# left ما نمایندگان هم گفتیم
# [46752, 2964, 5098, 2820, 10709]
# برخورد میکند
# [3878, 2980]
# پس شما میبینید برخوردهای سلبی این چنینی خیلی سریع و فوری صورت میگیرد
# [2965, 3124, 8146, 18226, 30909, 2802, 21852, 3805, 4861, 1379, 10286, 3080, 3858]
# ما واقعا از وزیر کشور و نیروی انتظامی انتظار داشتیم که بلافاصله اقدامی صورت دهند .
# [2964, 5668, 2791, 3646, 2930, 1379, 4290, 7719, 4378, 7363, 2800, 7856, 8813, 3080, 4577, 1012]
# اما الان معلوم نیست چه سیاستی برای مواجهه با این ماجرا در پیش گرفته شده
# [2949, 5971, 7544, 3152, 3051, 16221, 2831, 10425, 2799, 2802, 6518, 2786, 2958, 3296, 2871]
# و چه بسا مدل برخورد برعکس شده باشد
# [1379, 3051, 16337, 3945, 3878, 10532, 2871, 3048]
# زیرا صحبتهای جدیدی مطرح شده است .
# [4140, 9807, 5019, 4084, 2871, 2806, 1012]
# حالا برای تبریه کردن فردی <*> موارد دیگری مطرح شده است .
# [4888, 2831, 29710, 2008, 3274, 5079, 1016, 1008, 1018, 3907, 3574, 4084, 2871, 2806, 1012]
# حالا برای تبریه کردن فردی <*> موارد دیگری مطرح شده است .
# [4888, 2831, 29710, 2008, 3274, 5079, 1016, 1008, 1018, 3907, 3574, 4084, 2871, 2806, 1012]
# چیزی که برای من نگرانکننده است و واقعا جای تاسف دارد ، این که چه اصراری توسط بعضیها وجود دارد
# [4082, 2800, 2831, 2842, 22879, 2806, 1379, 5668, 3206, 13118, 2924, 1348, 2802, 2800, 3051, 41398, 3158, 13364, 3022, 2924]
# left باید به این نکته توجه کنیم
# [46752, 3013, 2789, 2802, 4909, 3211, 3592]
# چیزی که برای من نگرانکننده است و واقعا جای تاسف دارد ، این که چه اصراری توسط بعضیها وجود دارد
# [4082, 2800, 2831, 2842, 22879, 2806, 1379, 5668, 3206, 13118, 2924, 1348, 2802, 2800, 3051, 41398, 3158, 13364, 3022, 2924]
# که در بسیاری موارد مردم برای آنکه نارضایتی خود را نشان دهند دست به حرکاتی میزنند
# [2800, 2786, 3398, 3907, 3155, 2831, 4695, 12206, 2847, 2803, 3228, 4577, 2910, 2789, 32934, 8343]
# left متاسفانه به جای این که سعی کنیم از آجرها و قطعات دیوار بلند بیاعتمادی <*> کم کنیم ،
# [46752, 5571, 2789, 3206, 2802, 2800, 4789, 3592, 2791, 35979, 1379, 6072, 5397, 4384, 25424, 1016, 1008, 1018, 2961, 3592, 1348]
# متاسفانه به جای این که سعی کنیم از آجرها و قطعات دیوار بلند بیاعتمادی <*> کم کنیم ،
# [5571, 2789, 3206, 2802, 2800, 4789, 3592, 2791, 35979, 1379, 6072, 5397, 4384, 25424, 1016, 1008, 1018, 2961, 3592, 1348]
# متاسفانه به جای این که سعی کنیم از آجرها و قطعات دیوار بلند بیاعتمادی <*> کم کنیم ،
# [5571, 2789, 3206, 2802, 2800, 4789, 3592, 2791, 35979, 1379, 6072, 5397, 4384, 25424, 1016, 1008, 1018, 2961, 3592, 1348]
# روز به روز به این قطعات ، اضافه میکنیم ،
# [2991, 2789, 2991, 2789, 2802, 6072, 1348, 4241, 4279, 1348]
# به گونهای که کسانی <*> در یک طرف قرار گرفتهاند و مردم در طرف دیگر .
# [2789, 5793, 2800, 4499, 1016, 1008, 1018, 2786, 2829, 3583, 2959, 6449, 1379, 3155, 2786, 3583, 2972, 1012]
# left حتی اگر بخواهند بپذیرند یا نپذیرند ،
# [46752, 3466, 3064, 12095, 18532, 2880, 60162, 1348]
# [2786, 3747, 2800, 2802, 4704, 2786, 4610, 3109, 3271, 1379, 2786, 3753, 19016, 3826, 74456, 1348, 10366, 1348, 11108, 1379, 11143, 2802, 5082, 3400, 4504, 3271, 2806, 1012]
# از آن سو درآمدهای دولت هم افزایش مییابد . <*> کسانی
# [2791, 2808, 3156, 8216, 3099, 2820, 3191, 5277, 1012, 1016, 1008, 1018, 4499]
# از آن سو درآمدهای دولت هم افزایش مییابد . <*> کسانی
# [2791, 2808, 3156, 8216, 3099, 2820, 3191, 5277, 1012, 1016, 1008, 1018, 4499]
# left درآمدهای آنها قابل رصد و پیگیری است .
# [46752, 8216, 2950, 3496, 9194, 1379, 5960, 2806, 1012]
# در حالی که این شاخص در ترکیه ۲۰ درصد و در کشورهای اسکاندیناوی مثل سوید ، نروژ ، دانمارک و فنلاند این رقم حدود ۵۰ درصد است .
# [2786, 3747, 2800, 2802, 4704, 2786, 4610, 3109, 3271, 1379, 2786, 3753, 19016, 3826, 74456, 1348, 10366, 1348, 11108, 1379, 11143, 2802, 5082, 3400, 4504, 3271, 2806, 1012]
# left شما توجه کنید
# [46752, 3124, 3211, 3116]
# سازمانهای اطلاعاتی و امنیتی کشور میتوانند این درآمدها را رصد کنند .
# [6801, 5823, 1379, 5725, 2930, 3918, 2802, 17575, 2803, 9194, 3168, 1012]
# سازمانهای اطلاعاتی و امنیتی کشور میتوانند این درآمدها را رصد کنند .
# [6801, 5823, 1379, 5725, 2930, 3918, 2802, 17575, 2803, 9194, 3168, 1012]
# و اگر شما این عدد را در ۴۵۰۰ تومان ضرب کنید
# [1379, 3064, 3124, 2802, 5444, 2803, 2786, 24128, 3832, 6240, 3116]
# left این فقط یک قلم پولشویی است
# [46752, 2802, 3765, 2829, 5892, 15089, 2806]
# سازمانهای اطلاعاتی و امنیتی کشور میتوانند این درآمدها را رصد کنند .
# [6801, 5823, 1379, 5725, 2930, 3918, 2802, 17575, 2803, 9194, 3168, 1012]
# سازمانهای اطلاعاتی و امنیتی کشور میتوانند این درآمدها را رصد کنند .
# [6801, 5823, 1379, 5725, 2930, 3918, 2802, 17575, 2803, 9194, 3168, 1012]
# خب من که کالای قاچاق وارد کشور نکرده ام ،
# [8039, 2842, 2800, 7402, 6125, 3332, 2930, 5938, 2822, 1348]
# left ۵۰ هزار میلیارد تومان که از طریق چمدان رد و بدل نمیشود ،
# [46752, 4504, 3245, 3742, 3832, 2800, 2791, 3626, 14969, 5095, 1379, 8842, 4684, 1348]
# اما مبارزه با پولشویی را در دستور کار قرار ندهیم .
# [2949, 4873, 2799, 15089, 2803, 2786, 4090, 2867, 2959, 22880, 1012]
# این تبادلات مالی از طریق همین سیستم بانکی صورت میگیرد .
# [2802, 23437, 3491, 2791, 3626, 3241, 3521, 4243, 3080, 3858, 1012]
# در واقع وقتی از پولشویی گسترده در اقتصاد ایران سخن میگوییم
# [2786, 3473, 3711, 2791, 15089, 5223, 2786, 3563, 2927, 4402, 11286]
# left و کاملا یک حرف اقتصادی میزنیم
# [46752, 1379, 4335, 2829, 3919, 3433, 17346]
# left که در قالب اعداد امکان مطالعه دارد .
# نمایشگاه « عطر سیب » <*> برای حمایت از هیاتهای مذهبی و تکریم ایام محرم توسط شهرداری تهران برگزار میشود .
# [5430, 1064, 11161, 6723, 1078, 1016, 1008, 1018, 2831, 3876, 2791, 17498, 5648, 1379, 19577, 7547, 11452, 3158, 5497, 3326, 4004, 2886, 1012]
# این حمایتها هر ساله بخش قابل توجهی از منابع شهرداری تهران را به خود اختصاص داده
# [2802, 25591, 2937, 4502, 3108, 3496, 5739, 2791, 3870, 5497, 3326, 2803, 2789, 2847, 4533, 3171]
# left عضو شورای شهر معتقد است
# [46752, 4179, 3727, 2979, 4569, 2806]
# این حمایتها هر ساله بخش قابل توجهی از منابع شهرداری تهران را به خود اختصاص داده
# [2802, 25591, 2937, 4502, 3108, 3496, 5739, 2791, 3870, 5497, 3326, 2803, 2789, 2847, 4533, 3171]
# « بودجه شهرداری از عوارض پرداخت شده توسط مردم تامین میشود
# [1064, 4925, 5497, 2791, 6697, 3486, 2871, 3158, 3155, 3823, 2886]
# و میباید صرف نگهداشت و امور شهر شود
# [1379, 23193, 4217, 30646, 1379, 4118, 2979, 3073]
# و نباید عوارض مردم خرج مواردی شود
# [1379, 4719, 6697, 3155, 8850, 6316, 3073]
# left به گفته خداکرمی
# [46752, 2789, 3538, 87270]
# شهرداری تهران تصمیم گرفته همچون سالهای گذشته ، امسال نیز در ایام محرم نمایشگاه « عطر سیب » را برگزار کند .
# [5497, 3326, 3835, 3296, 4553, 3816, 3421, 1348, 4955, 2921, 2786, 7547, 11452, 5430, 1064, 11161, 6723, 1078, 2803, 4004, 3054, 1012]
# تحمیل چنین هزینههایی به شهر خلاف مصوبه شورای شهر است
# [9367, 3677, 25082, 2789, 2979, 6163, 7104, 3727, 2979, 2806]
# left وی اعلام کرده
# [46752, 2931, 3402, 3027]
# تحمیل چنین هزینههایی به شهر خلاف مصوبه شورای شهر است
# [9367, 3677, 25082, 2789, 2979, 6163, 7104, 3727, 2979, 2806]
# شهردار قصد دارد از محل بودجهی در اختیار برای این نمایشگاه هزینه کند
# [8486, 4790, 2924, 2791, 3733, 25347, 2786, 4209, 2831, 2802, 5430, 4001, 3054]
# left طبق اعلام این عضو شورای شهر تهران ،
# [46752, 4173, 3402, 2802, 4179, 3727, 2979, 3326, 1348]
# شهردار قصد دارد از محل بودجهی در اختیار برای این نمایشگاه هزینه کند
# [8486, 4790, 2924, 2791, 3733, 25347, 2786, 4209, 2831, 2802, 5430, 4001, 3054]
# left سیفالله ابوترابی ، سخنگوی سازمان ثبت احوال کشور ، در این باره گفته :
# [46752, 40067, 34511, 1348, 7417, 3270, 4002, 12164, 2930, 1348, 2786, 2802, 6274, 3538, 1014]
# دلیل تاخیر صدور کارت ملی هوشمند وارداتی بودن بدنه کارت ملی است .
# [3310, 7429, 6359, 5108, 3333, 4980, 9326, 3798, 7349, 5108, 3333, 2806, 1012]
# « متاسفانه <*> دیگر نمیتوانیم بدنه کارت را وارد کنیم .
# [1064, 5571, 1016, 1008, 1018, 2972, 9990, 7349, 5108, 2803, 3332, 3592, 1012]
# « متاسفانه <*> دیگر نمیتوانیم بدنه کارت را وارد کنیم .
# [1064, 5571, 1016, 1008, 1018, 2972, 9990, 7349, 5108, 2803, 3332, 3592, 1012]
# left او در ادامه گفت :
# [46752, 2866, 2786, 3251, 3017, 1014]
# « متاسفانه <*> دیگر نمیتوانیم بدنه کارت را وارد کنیم .
# [1064, 5571, 1016, 1008, 1018, 2972, 9990, 7349, 5108, 2803, 3332, 3592, 1012]
# « شرکت متولی واردکننده کارت ملی تاکنون همکاری خوبی با ثبت احوال داشته
# [1064, 3052, 10309, 19067, 5108, 3333, 4971, 3909, 3949, 2799, 4002, 12164, 3151]
# اما طبیعی است <*> هزینه واردات بالا رفته باشد
# [2949, 4105, 2806, 1016, 1008, 1018, 4001, 5367, 3683, 4708, 3048]
# اما طبیعی است <*> هزینه واردات بالا رفته باشد
# [2949, 4105, 2806, 1016, 1008, 1018, 4001, 5367, 3683, 4708, 3048]
# « شرکت متولی واردکننده کارت ملی تاکنون همکاری خوبی با ثبت احوال داشته
# [1064, 3052, 10309, 19067, 5108, 3333, 4971, 3909, 3949, 2799, 4002, 12164, 3151]
# این در حالی است
# [2802, 2786, 3747, 2806]
# دلیل تاخیر صدور کارت ملی هوشمند وارداتی بودن بدنه کارت ملی است .
# [3310, 7429, 6359, 5108, 3333, 4980, 9326, 3798, 7349, 5108, 3333, 2806, 1012]
# سازمان ثبت احوال اقدامات اولیه برای تولید داخلی بدنه کارتها را انجام داده
# [3270, 4002, 12164, 4860, 4461, 2831, 3114, 3843, 7349, 17565, 2803, 3096, 3171]
# سازمان ثبت احوال اقدامات اولیه برای تولید داخلی بدنه کارتها را انجام داده
# [3270, 4002, 12164, 4860, 4461, 2831, 3114, 3843, 7349, 17565, 2803, 3096, 3171]
# کارت ملی تولید داخل باید برای بیش از ۴۰ میلیون نفر <*> صادر شود .
# [5108, 3333, 3114, 4127, 3013, 2831, 3385, 2791, 4743, 3399, 3432, 1016, 1008, 1018, 4591, 3073, 1012]
# left در هفتههای پایانی ریاست جمهوری باراک حسین اوباما ، سنای آمریکا با ۹۹ رای موافق و بدون رای مخالف طرح قانونی شده تحریمهای ایران ، معروف به داماتو را برای یک دوره ١۰ساله دیگر تمدید کرد .
# [46752, 2786, 11702, 6591, 4344, 3697, 14837, 4726, 9442, 1348, 17231, 3307, 2799, 8890, 3537, 5688, 1379, 3557, 3537, 5199, 3512, 4930, 2871, 7286, 2927, 1348, 4387, 2789, 66071, 2803, 2831, 2829, 3511, 1383, 2058, 9243, 2972, 9406, 2830, 1012]
# در هفتههای پایانی ریاست جمهوری باراک حسین اوباما ، سنای آمریکا با ۹۹ رای موافق و بدون رای مخالف طرح قانونی شده تحریمهای ایران ، معروف به داماتو را برای یک دوره ١۰ساله دیگر تمدید کرد .
# [2786, 11702, 6591, 4344, 3697, 14837, 4726, 9442, 1348, 17231, 3307, 2799, 8890, 3537, 5688, 1379, 3557, 3537, 5199, 3512, 4930, 2871, 7286, 2927, 1348, 4387, 2789, 66071, 2803, 2831, 2829, 3511, 1383, 2058, 9243, 2972, 9406, 2830, 1012]
# [3632, 66071, 1016, 1008, 1018, 14323, 3497, 4604, 2786, 3768, 3420, 1379, 4235, 2927, 2803, 2789, 3507, 14210, 2830]
# ایران باید سهم خود را به میزان قبل از تحریمها به دست بیاورد ؛
# [2927, 3013, 4759, 2847, 2803, 2789, 3669, 3556, 2791, 6581, 2789, 2910, 8993, 1349]
# left این کلام وزیر کارساز شد
# [46752, 2802, 7971, 3646, 19758, 2817]
# ایران باید سهم خود را به میزان قبل از تحریمها به دست بیاورد ؛
# [2927, 3013, 4759, 2847, 2803, 2789, 3669, 3556, 2791, 6581, 2789, 2910, 8993, 1349]
# و بعد از سه سال و چند ماه از آن روز سرانجام در وین وزرای نفتی اوپک پذیرفتند
# [1379, 3082, 2791, 3140, 2844, 1379, 3102, 3125, 2791, 2808, 2991, 5467, 2786, 6812, 10224, 5203, 7763, 18676]
# که هم تولید نفت را برای تعادل بازار کم کنند
# [2800, 2820, 3114, 3420, 2803, 2831, 7203, 3179, 2961, 3168]
# left وقتی با وجود اعتبار قانون داماتو ایران توانست بر مشکلات سر راه خود درباره میزان استخراج و فروش و بازاریابی نفت فایق آید ،
# [46752, 3711, 2799, 3022, 4699, 3632, 66071, 2927, 4542, 2801, 3966, 2892, 3148, 2847, 3424, 3669, 8269, 1379, 3569, 1379, 8032, 3420, 52821, 5154, 1348]
# وقتی با وجود اعتبار قانون داماتو ایران توانست بر مشکلات سر راه خود درباره میزان استخراج و فروش و بازاریابی نفت فایق آید ،
# [3711, 2799, 3022, 4699, 3632, 66071, 2927, 4542, 2801, 3966, 2892, 3148, 2847, 3424, 3669, 8269, 1379, 3569, 1379, 8032, 3420, 52821, 5154, 1348]
# ایران باید سهم خود را به میزان قبل از تحریمها به دست بیاورد ؛
# [2927, 3013, 4759, 2847, 2803, 2789, 3669, 3556, 2791, 6581, 2789, 2910, 8993, 1349]
# left تغییر دولت در آمریکا تاثیری در نگاه آمریکاییان نخواهد داشت .
# [46752, 3320, 3099, 2786, 3307, 9534, 2786, 4407, 34808, 4969, 2996, 1012]
# left می دانیم حتی اگر خانم کلینتون هم برنده انتخابات میشد ،
# [46752, 2793, 95593, 3466, 3064, 6145, 12880, 2820, 5689, 3958, 3578, 1348]
# تغییر دولت در آمریکا تاثیری در نگاه آمریکاییان نخواهد داشت .
# [3320, 3099, 2786, 3307, 9534, 2786, 4407, 34808, 4969, 2996, 1012]
# حال پرسش این است
# [3035, 6933, 2802, 2806]
# left براساس روش قانون گذاری در آمریکا ،
# [46752, 4580, 3541, 3632, 4604, 2786, 3307, 1348]
# حال پرسش این است
# [3035, 6933, 2802, 2806]
# طرحی <*> به سنا ارسال میشود
# [10138, 1016, 1008, 1018, 2789, 10827, 4855, 2886]
# left و در صورت تصویب سنا
# [46752, 1379, 2786, 3080, 5012, 10827]
# طرحی <*> به سنا ارسال میشود
# [10138, 1016, 1008, 1018, 2789, 10827, 4855, 2886]
# left تا اگر مصوبه را امضا کرد ،
# [46752, 2848, 3064, 7104, 2803, 5873, 2830, 1348]
# برای صدور دستور اجرا به دفتر رییس جمهوری فرستاده میشود
# [2831, 6359, 4090, 4129, 2789, 5236, 4800, 3697, 7951, 2886]
# طرحی <*> به سنا ارسال میشود
# [10138, 1016, 1008, 1018, 2789, 10827, 4855, 2886]
# رییس جمهوری آمریکا از این اختیار برخوردار است
# [4800, 3697, 3307, 2791, 2802, 4209, 4874, 2806]
# که مصوبه مجلس را وتو کند
# [2800, 7104, 3590, 2803, 28497, 3054]
# و در مقابل ، نمایندگان مجلس هم از این اختیار
# [1379, 2786, 4029, 1348, 5098, 3590, 2820, 2791, 2802, 4209]
# برخوردار
# [4874]
# ند
# [3487]

# %%
print(label_dict)
# Out:
# {'evaluation': 0, 'joint': 1, 'condition': 2, 'manner-means': 3, 'comparison': 4, 'background': 5, 'cause': 6, 'temporal': 7, 'contrast': 8, 'attribution': 9, 'topicomment': 10, 'topichange': 11, 'summary': 12, 'enablement': 13, 'elaboration': 14, 'explanation': 15, 'topidrift': 16}

# %% [markdown]
# # Define the model

# %% [markdown]
# ## load pretrained model

# %%
from transformers import BertForSequenceClassification, AdamW
from torch import optim

model = BertForSequenceClassification.from_pretrained(BERT_MODEL, num_labels=len(label_dict)).to(device)
optimizer = AdamW(model.parameters(), lr=2e-5, correct_bias=False)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.6, mode='max', patience=2, min_lr=5e-7, verbose=True)
# Out:
# Some weights of the model checkpoint at HooshvareLab/bert-fa-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at HooshvareLab/bert-fa-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
from CategoricalAccuracy import CategoricalAccuracy as CA
import numpy as np

ca = CA()

x = torch.tensor(np.array([[[1,0,0], [1,0,0], [1,0,0]]]))
y1 = torch.tensor(np.array([[0], [1], [1]]))
y2 = torch.tensor(np.array([[0], [0], [0]]))

ca(x,y1)
print(ca.get_metric(reset=True))
ca(x,y2)
print(ca.get_metric(reset=True))
# Out:
# 0.3333333333333333
# 1.0

# %% [markdown]
# ## define evaulation metric

# %%
# to evaluate model for train and test. And also use classification report for testing
import torch.nn as nn
import matplotlib.pyplot as plt
import seaborn as sns

# helper function to calculate the batch accuracy
def multi_acc(y_pred, y_test, allennlp=False):
  if allennlp==False:
    acc = (torch.log_softmax(y_pred, dim=1).argmax(dim=1) == y_test).sum().float() / float(y_test.size(0))
    return acc

def save_cm(y_true, y_pred, target_names, display_zeros=True):
  confusion_matrix = pd.crosstab(y_true, y_pred)
  print(confusion_matrix)
  target_namesx = confusion_matrix.columns
  target_namesy = confusion_matrix.index.values

  fig, ax = plt.subplots(figsize=(10,10))
  s = sns.heatmap(confusion_matrix, xticklabels=target_namesx, yticklabels=target_namesy, annot=True, fmt = '.5g')

  plt.title('CM predicted v actual values')
  plt.xlabel('Pred')
  plt.ylabel('True')
  plt.tight_layout()
  # plt.show()
  # plt.savefig(image_file+exp+'.png')
  # print(image_file+exp+'.png')

# freeze model weights and measure validation / test 
def evaluate_accuracy(model, optimizer, data_loader, rev_label_dict, label_dict, save_path, is_training=True):
  model.eval()
  total_val_acc  = 0
  total_val_loss = 0
  
  #for classification report
  y_true = []
  y_pred = []
  idx_list = []
  premise_list = []
  hypo_list = []
  idx_map = mnli_dataset.val_idx if is_training else mnli_dataset.test_idx

  with torch.no_grad():
    for batch_idx, (pair_token_ids, mask_ids, seg_ids, y, idx) in enumerate(data_loader):      
      optimizer.zero_grad()
      pair_token_ids = pair_token_ids.to(device)
      mask_ids = mask_ids.to(device)
      seg_ids = seg_ids.to(device)
      labels = y.to(device)
      
      # loss, prediction = model(pair_token_ids, 
      #                       token_type_ids=seg_ids, 
      #                       attention_mask=mask_ids, 
      #                       labels=labels).values()
      # acc = multi_acc(prediction, labels)

      ############new code#####################

      outputs = model(pair_token_ids, 
                            token_type_ids=seg_ids, 
                            attention_mask=mask_ids)
      # probs = F.softmax(outputs, dim=1)
      # max_idx = torch.max(outputs, 1).indices
      # one_hot = F.one_hot(max_idx, outputs.shape[1])

      criterion = nn.CrossEntropyLoss()
      loss = criterion(outputs, labels)
      acc = multi_acc(outputs, labels)
      ########################################

      total_val_loss += loss.item()
      total_val_acc  += acc.item()

      # log predictions for classification report
      argmax_predictions = torch.argmax(outputs,dim=1).tolist()
      labels_list = labels.tolist()
      assert(len(labels_list)==len(argmax_predictions))
      for p in argmax_predictions: y_pred.append(rev_label_dict[int(p)])
      for l in labels_list: y_true.append(rev_label_dict[l])
      for i in idx.tolist():
        idx_list.append(i)
        premise_list.append(idx_map[i][0])
        hypo_list.append(idx_map[i][1])

  val_acc  = total_val_acc/len(data_loader)
  val_loss = total_val_loss/len(data_loader)
  cr = classification_report(y_true, y_pred)

  idx_json = {'idx': idx_list, 'gold_label': y_true, 'pred_label': y_pred, 'premise': premise_list, 'hypothesis': hypo_list}
  if not is_training: json.dump(idx_json, open(save_path, 'w', encoding='utf8'), ensure_ascii=False)

  # if not is_training:
  #   save_cm(y_true, y_pred, rev_label_dict)
  
  return val_acc, val_loss, cr, model, optimizer

# %% [markdown]
# ## define bert custom model

# %%
from transformers import BertModel, AutoTokenizer
import torch.nn as nn
class CustomBERTModel(nn.Module):
    #https://stackoverflow.com/questions/64156202/add-dense-layer-on-top-of-huggingface-bert-model
    def __init__(self, num_labels):
          super(CustomBERTModel, self).__init__()
          self.num_classes = num_labels+1 # zero indexed classes
          print('ASSIGN:', self.num_classes)
          self.bert = BertModel.from_pretrained(BERT_MODEL)
          ### New layers:
          self.linear1 = nn.Linear(768, 512)
          self.linear2 = nn.Linear(512, 256)
          self.linear3 = nn.Linear(256, 128)
          self.linear4 = nn.Linear(128, self.num_classes)
          self.act1 = nn.ReLU() # can i use the same activation object everywhere?
          self.act2 = nn.ReLU()
          self.act3 = nn.ReLU()
          self.drop = nn.Dropout(0.1) 

    def forward(self, pair_token_ids, token_type_ids, attention_mask):
        sequence_output, pooled_output = self.bert(input_ids=pair_token_ids, 
                        token_type_ids=token_type_ids, 
                        attention_mask=attention_mask).values()

        # sequence_output has the following shape: (batch_size, sequence_length, 768)
        linear1_output = self.linear1(sequence_output[:,0,:].view(-1,768)) ## extract the 1st token's embeddings
        linear1_output = self.act1(linear1_output)
        linear2_output = self.linear2(linear1_output)
        linear2_output = self.act2(linear2_output)
        linear3_output = self.linear3(linear2_output)
        linear3_output = self.act3(linear3_output)
        linear4_output = self.linear4(linear3_output)
        drop_output = self.drop(linear4_output)
        return drop_output# loss, outputs

# tokenizer = AutoTokenizer.from_pretrained(BERT_MODEL)
model = CustomBERTModel(mnli_dataset.num_labels) # You can pass the parameters if required to have more flexible model
model.to(device) ## can be gpu
optimizer = AdamW(model.parameters(), lr=2e-5, correct_bias=False)
# Out:
# ASSIGN: 18
# Some weights of the model checkpoint at HooshvareLab/bert-fa-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %% [markdown]
# ## define training regime

# %%
### MODIFIED
import time
import traceback
import torch.nn.functional as F
from typing import Optional, Iterable, Dict, Any
from EarlyStopperUtil import MetricTracker


from sklearn.metrics import classification_report

EPOCHS = 100

def train(model, train_loader, val_loader, optimizer, scheduler, rev_label_dict):  
  EarlyStopper = MetricTracker(patience=12, metric_name='+accuracy')

  for epoch in range(EPOCHS):
    start = time.time()
    model.train()
    total_train_loss = 0
    total_train_acc  = 0

    # logging for scheduler
    losses = []
    accuracies= []

    train_size = 0

    for batch_idx, (pair_token_ids, mask_ids, seg_ids, y, idx) in enumerate(train_loader):
      train_size+=1
      optimizer.zero_grad()
      pair_token_ids = pair_token_ids.to(device)
      mask_ids = mask_ids.to(device)
      seg_ids = seg_ids.to(device)
      labels = y.to(device)

      ############new code#####################

      outputs = model(pair_token_ids, 
                            token_type_ids=seg_ids, 
                            attention_mask=mask_ids)
      # outputs = F.log_softmax(outputs, dim=1) # log prob
      # outputs = np.argmax(prob, axis=1) # preds
      # https://stackoverflow.com/questions/43672047/convert-probability-vector-into-target-vector-in-python
      # https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html
      criterion = nn.CrossEntropyLoss()
      loss = criterion(outputs, labels)
      loss.backward()
      acc = multi_acc(outputs, labels)
      optimizer.step()
      ################old code#################

      # loss, prediction = model(pair_token_ids, 
      #                       token_type_ids=seg_ids, 
      #                       attention_mask=mask_ids, 
      #                       labels=labels).values()

      # acc = multi_acc(prediction, labels)
      # loss.backward()
      # optimizer.step()

      ########################################
      total_train_loss += loss.item()
      total_train_acc  += acc.item()

      # log losses for scheduler
      losses.append(loss)
      accuracies.append(acc)
      mean_loss = sum(losses)/len(losses)
      scheduler.step(mean_loss)


    train_acc  = total_train_acc/len(train_loader)
    train_loss = total_train_loss/len(train_loader)

    val_acc, val_loss, cr, model, optimizer = evaluate_accuracy(model, optimizer, val_loader, rev_label_dict, label_dict, None)
    EarlyStopper.add_metric(val_acc)
    if EarlyStopper.should_stop_early(): break

    end = time.time()
    hours, rem = divmod(end-start, 3600)
    minutes, seconds = divmod(rem, 60)

    print(f'Epoch {epoch+1}: train_loss: {train_loss:.4f} train_acc: {train_acc:.4f} | val_loss: {val_loss:.4f} val_acc: {val_acc:.4f}')
    print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
    print(f'train_size: {train_size}')

# %%
import warnings
from sklearn.exceptions import DataConversionWarning
with warnings.catch_warnings():
    warnings.simplefilter("ignore")

    train(model, train_loader, val_loader, optimizer, scheduler, rev_label_dict)
# Out:
# Epoch 00006: reducing learning rate of group 0 to 1.2000e-05.
# Epoch 00009: reducing learning rate of group 0 to 7.2000e-06.
# Epoch 00012: reducing learning rate of group 0 to 4.3200e-06.
# Epoch 00015: reducing learning rate of group 0 to 2.5920e-06.
# Epoch 00018: reducing learning rate of group 0 to 1.5552e-06.
# Epoch 00021: reducing learning rate of group 0 to 9.3312e-07.
# Epoch 00024: reducing learning rate of group 0 to 5.5987e-07.
# Epoch 00027: reducing learning rate of group 0 to 5.0000e-07.
# Epoch 1: train_loss: 2.3551 train_acc: 0.2425 | val_loss: 2.0133 val_acc: 0.2927
# 00:00:26.45
# train_size: 402
# Epoch 2: train_loss: 2.1908 train_acc: 0.3315 | val_loss: 1.9599 val_acc: 0.3860
# 00:00:26.25
# train_size: 402
# Epoch 3: train_loss: 2.1291 train_acc: 0.3619 | val_loss: 1.8841 val_acc: 0.3987
# 00:00:26.29
# train_size: 402
# Epoch 4: train_loss: 2.1270 train_acc: 0.3053 | val_loss: 1.9380 val_acc: 0.3493
# 00:00:26.18
# train_size: 402
# Epoch 5: train_loss: 2.0558 train_acc: 0.3576 | val_loss: 1.8400 val_acc: 0.4267
# 00:00:26.12
# train_size: 402
# Epoch 6: train_loss: 1.9215 train_acc: 0.4179 | val_loss: 1.7985 val_acc: 0.4193
# 00:00:26.13
# train_size: 402
# Epoch 7: train_loss: 1.9828 train_acc: 0.3937 | val_loss: 1.7910 val_acc: 0.4533
# 00:00:26.30
# train_size: 402
# Epoch 8: train_loss: 1.9339 train_acc: 0.3961 | val_loss: 1.7415 val_acc: 0.4553
# 00:00:26.30
# train_size: 402
# Epoch 9: train_loss: 1.8406 train_acc: 0.4248 | val_loss: 1.7270 val_acc: 0.4600
# 00:00:26.11
# train_size: 402
# Epoch 10: train_loss: 1.8763 train_acc: 0.4210 | val_loss: 1.7466 val_acc: 0.4453
# 00:00:26.25
# train_size: 402
# Epoch 11: train_loss: 1.7233 train_acc: 0.4757 | val_loss: 1.7549 val_acc: 0.4687
# 00:00:26.23
# train_size: 402
# Epoch 12: train_loss: 1.7784 train_acc: 0.4565 | val_loss: 1.7628 val_acc: 0.4320
# 00:00:26.13
# train_size: 402
# Epoch 13: train_loss: 1.7028 train_acc: 0.4795 | val_loss: 1.7252 val_acc: 0.4707
# 00:00:26.02
# train_size: 402
# Epoch 14: train_loss: 1.5907 train_acc: 0.5044 | val_loss: 1.7526 val_acc: 0.4840
# 00:00:26.24
# train_size: 402
# Epoch 15: train_loss: 1.6083 train_acc: 0.5286 | val_loss: 1.7077 val_acc: 0.4947
# 00:00:26.23
# train_size: 402
# Epoch 16: train_loss: 1.5175 train_acc: 0.5392 | val_loss: 1.8191 val_acc: 0.4340
# 00:00:25.98
# train_size: 402
# Epoch 17: train_loss: 1.4387 train_acc: 0.5672 | val_loss: 1.8101 val_acc: 0.4547
# 00:00:26.04
# train_size: 402
# Epoch 18: train_loss: 1.4441 train_acc: 0.5684 | val_loss: 1.8431 val_acc: 0.4613
# 00:00:26.22
# train_size: 402
# Epoch 19: train_loss: 1.3710 train_acc: 0.5846 | val_loss: 1.8838 val_acc: 0.4327
# 00:00:26.00
# train_size: 402
# Epoch 20: train_loss: 1.3194 train_acc: 0.6076 | val_loss: 1.7921 val_acc: 0.4713
# 00:00:26.11
# train_size: 402
# Epoch 21: train_loss: 1.2415 train_acc: 0.6250 | val_loss: 1.8987 val_acc: 0.4707
# 00:00:26.14
# train_size: 402
# Epoch 22: train_loss: 1.2372 train_acc: 0.6300 | val_loss: 1.8561 val_acc: 0.4753
# 00:00:26.41
# train_size: 402
# Epoch 23: train_loss: 1.1892 train_acc: 0.6424 | val_loss: 1.9383 val_acc: 0.4680
# 00:00:25.93
# train_size: 402
# Epoch 24: train_loss: 1.0923 train_acc: 0.6760 | val_loss: 2.0263 val_acc: 0.4547
# 00:00:26.24
# train_size: 402
# Epoch 25: train_loss: 1.0876 train_acc: 0.6760 | val_loss: 2.0622 val_acc: 0.4520
# 00:00:26.20
# train_size: 402
# Epoch 26: train_loss: 1.0641 train_acc: 0.6648 | val_loss: 2.1540 val_acc: 0.4527
# 00:00:25.90
# train_size: 402

# %%
save_path = 'bert-disrpt_fas_'+str(batch_size)+'X'+str(batches_per_epoch)+'_refactor_2.pt'
torch.save(model.state_dict(), save_path)

# %% [markdown]
# # test

# %%
def validate(model, test_loader, optimizer, rev_label_dict, label_dict, save_path):
  start = time.time()
  test_acc, test_loss, cr, model, optimizer = evaluate_accuracy(model, optimizer, test_loader, rev_label_dict, label_dict, save_path.replace('.pt', '.json'), is_training=False)
  end = time.time()
  hours, rem = divmod(end-start, 3600)
  minutes, seconds = divmod(rem, 60)

  print(f'Test_loss: {test_loss:.4f} test_acc: {test_acc:.4f}')
  print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
  print(cr)

  return test_loss, test_acc


model.load_state_dict(torch.load(save_path))
test_loss, test_acc = validate(model, test_loader, optimizer, rev_label_dict, label_dict, save_path)
print(f'Test Loss: {test_loss:.3f} |  Test Acc: {test_acc*100:.2f}%')
# Out:
# Test_loss: 2.3098 test_acc: 0.4189
# 00:00:01.61
#               precision    recall  f1-score   support
#
#  attribution       0.67      0.51      0.58        39
#   background       0.37      0.68      0.48        31
#        cause       0.14      0.37      0.20        35
#   comparison       0.00      0.00      0.00         5
#    condition       1.00      0.13      0.24        15
#     contrast       0.49      0.44      0.47        54
#  elaboration       0.62      0.61      0.62       153
#   enablement       0.50      0.55      0.52        11
#   evaluation       0.15      0.16      0.16        25
#  explanation       0.13      0.22      0.16        45
#        joint       0.68      0.47      0.55       116
# manner-means       0.00      0.00      0.00         7
#      summary       0.00      0.00      0.00        16
#     temporal       0.00      0.00      0.00        20
#   topichange       0.00      0.00      0.00         9
#  topicomment       0.00      0.00      0.00        11
#
#     accuracy                           0.42       592
#    macro avg       0.30      0.26      0.25       592
# weighted avg       0.46      0.42      0.42       592
#
# Test Loss: 2.310 |  Test Acc: 41.89%
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/VD/kaveri/anaconda3/envs/py310/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
